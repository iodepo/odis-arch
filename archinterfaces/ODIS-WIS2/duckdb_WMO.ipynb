# %% [markdown]
# # WMO Duckdb

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)  ## remove pandas future warning
import pandas as pd
import geopandas as gpd
from shapely import wkt
import fiona
import s3fs
import pyarrow.parquet as pq
import shapely
import os
import json
import re
import duckdb

# %%
def to_wkt(polygon_string):
    # split the input string into pairs
    pairs = polygon_string.split(',')

    # transform each pair into 'y x' format
    # transformed_pairs = [' '.join(reversed(pair.split())) for pair in pairs]
    transformed_pairs = [' '.join(pair.split()) for pair in pairs]


    # join the transformed pairs with a comma and a space
    transformed_string = ', '.join(transformed_pairs)

    # return the final WKT string
    return f"POLYGON (({transformed_string}))"

# %%
createCmd = '''CREATE TABLE base (id VARCHAR, type VARCHAR, name VARCHAR, url VARCHAR, description VARCHAR, headline VARCHAR, g VARCHAR );
CREATE TABLE dataset (id VARCHAR, type VARCHAR, sameAs VARCHAR, license VARCHAR, citation VARCHAR, keyword VARCHAR, includedInDataCatalog VARCHAR, distribution VARCHAR, region VARCHAR, provider VARCHAR, publisher VARCHAR, creator VARCHAR);
CREATE TABLE sup_time (id VARCHAR, type VARCHAR, time VARCHAR, temporalCoverage VARCHAR, dateModified VARCHAR, datePublished VARCHAR, );

COPY base FROM '/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_baseQuery.parquet';
COPY dataset FROM '/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_dataset.parquet';
COPY sup_time FROM '/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_sup_temporal.parquet';

CREATE TABLE course AS SELECT * FROM read_parquet('/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_course.parquet',  union_by_name=true);
CREATE TABLE person AS SELECT * FROM read_parquet('/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_person.parquet',  union_by_name=true);
CREATE TABLE sup_geo AS SELECT * FROM read_parquet('/home/fils/src/Projects/OIH/odis-arch/graphOps/extraction/mdp/output/*_sup_geo.parquet',  union_by_name=true);
'''

# %%
sqlCmd = '''SELECT base_agg.id, base_agg.type_list, base_agg.name_list, dataset_agg.kw_list,
        base_agg.b_url, base_agg.b_desc, base_agg.b_headline, geo_agg.geom_list,
        temporal_agg.tc_list, temporal_agg.dp_list
FROM (
    SELECT id, STRING_AGG(DISTINCT type, ', ') AS type_list, STRING_AGG(DISTINCT name, ', ') AS name_list,
           any_value(url) AS b_URL, any_value(description) AS b_desc, any_value(headline) AS b_headline
    FROM base
    GROUP BY  id
) AS base_agg
JOIN (
    SELECT id, ANY_VALUE(includedInDataCatalog), STRING_AGG(DISTINCT keyword, ', ') AS kw_list
    FROM dataset
    GROUP BY  id
) AS dataset_agg
    ON base_agg.id = dataset_agg.id
JOIN (
    SELECT id,  STRING_AGG(DISTINCT geom, ', ') AS geom_list
    FROM sup_geo
    GROUP BY  id
) AS geo_agg
    ON base_agg.id = geo_agg.id
JOIN (
    SELECT id,  STRING_AGG(DISTINCT temporalCoverage, ', ') AS tc_list,  STRING_AGG(DISTINCT datePublished, ', ') AS dp_list
    FROM sup_time
    GROUP BY  id
) AS temporal_agg
ON   base_agg.id = temporal_agg.id
ORDER By base_agg.id;
'''

# %%
con = duckdb.connect()
con.execute(createCmd)  # load from url

# %%
df = con.execute(sqlCmd).fetchdf()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12163 entries, 0 to 12162
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12163 non-null  object
#  1   type_list   12163 non-null  object
#  2   name_list   12163 non-null  object
#  3   kw_list     12163 non-null  object
#  4   b_URL       12163 non-null  object
#  5   b_desc      12163 non-null  object
#  6   b_headline  12163 non-null  object
#  7   geom_list   12163 non-null  object
#  8   tc_list     12163 non-null  object
#  9   dp_list     12163 non-null  object
# dtypes: object(10)
# memory usage: 950.4+ KB
# None

# %%
df.head(10)
# Out:
#                                                   id  \
# 0  https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1  https://catalogue.cioos.ca/dataset/00347450-75...
# 2  https://catalogue.cioos.ca/dataset/00347450-75...
# 3  https://catalogue.cioos.ca/dataset/00347450-75...
# 4  https://catalogue.cioos.ca/dataset/003ead14-1f...
# 5  https://catalogue.cioos.ca/dataset/003ead14-1f...
# 6  https://catalogue.cioos.ca/dataset/00863729-b5...
# 7  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
# 8  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
# 9  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
#
#                     type_list  \
# 0  https://schema.org/Dataset
# 1  https://schema.org/Dataset
# 2  https://schema.org/Dataset
# 3  https://schema.org/Dataset
# 4  https://schema.org/Dataset
# 5  https://schema.org/Dataset
# 6  https://schema.org/Dataset
# 7  https://schema.org/Dataset
# 8  https://schema.org/Dataset
# 9  https://schema.org/Dataset
#
#                                            name_list  \
# 0  Boundary Pass Conductivity Temperature Depth D...
# 1  Strait of Georgia East Capteur d'Oxygène déplo...
# 2  Strait of Georgia East Oxygen Sensor Deployed ...
# 3  Strait of Georgia East Capteur d'Oxygène déplo...
# 4  Patricia Bay Conductivité/Température/Profonde...
# 5  Patricia Bay Conductivité/Température/Profonde...
# 6  Barkley Canyon Upper Slope Capteur d'Oxygène d...
# 7  Ferme Cormorant de Cascadia Seaweed Turbidimèt...
# 8  Ferme Cormorant de Cascadia Seaweed Turbidimèt...
# 9  Cascadia Seaweed Cormorant Farm Turbidity Mete...
#
#                                              kw_list  \
# 0  speed_of_sound_in_sea_water, Subsurfacesalinit...
# 1  Oxygen, Subsurface temperature, volume_fractio...
# 2  Oxygène, Oceans, sea_water_temperature, Tempér...
# 3  Subsurface temperature, volume_fraction_of_oxy...
# 4  speed_of_sound_in_sea_water, Subsurfacesalinit...
# 5  Température sous la surface, sea_water_tempera...
# 6  Température sous la surface, sea_water_tempera...
# 7  Particulate matter, Matière particulaire, sea_...
# 8  Particulate matter, Matière particulaire, sea_...
# 9  Particulate matter, Matière particulaire, sea_...
#
#                                                b_URL  \
# 0  https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1  https://catalogue.cioos.ca/dataset/00347450-75...
# 2  https://catalogue.cioos.ca/dataset/00347450-75...
# 3  https://catalogue.cioos.ca/dataset/00347450-75...
# 4  https://catalogue.cioos.ca/dataset/003ead14-1f...
# 5  https://catalogue.cioos.ca/dataset/003ead14-1f...
# 6  https://catalogue.cioos.ca/dataset/00863729-b5...
# 7  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
# 8  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
# 9  https://catalogue.cioos.ca/dataset/0092e8bc-e9...
#
#                                               b_desc b_headline  \
# 0  The Sea-Bird Microcat SBE37SMP-ODO 9536 was de...       None
# 1  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 2  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 3  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 4  The Sea-Bird SeaCAT SBE16plus V2 6536 was depl...       None
# 5  The Sea-Bird SeaCAT SBE16plus V2 6536 was depl...       None
# 6  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 7  The Turner Cyclops-7F Fluorometer (S/N 900279)...       None
# 8  The Turner Cyclops-7F Fluorometer (S/N 900279)...       None
# 9  The Turner Cyclops-7F Fluorometer (S/N 900279)...       None
#
#                                            geom_list                tc_list  \
# 0    48.7662667 -123.0393167 48.7662667 -123.0393167  2018-10-26/2019-05-19
# 1                         -123.31687331, 49.04314848  2020-03-06/2020-09-24
# 2                         49.04314848, -123.31687331  2020-03-06/2020-09-24
# 3                         -123.31687331, 49.04314848  2020-03-06/2020-09-24
# 4  48.65136 -123.4864183333 48.65136 -123.4864183333  2011-10-02/2012-02-23
# 5  48.65136 -123.4864183333 48.65136 -123.4864183333  2011-10-02/2012-02-23
# 6            48.427373 -126.1743 48.427373 -126.1743  2019-05-16/2019-09-07
# 7                               49.25736, -125.92503  2022-05-25/2023-04-26
# 8                               49.25736, -125.92503  2022-05-25/2023-04-26
# 9                               49.25736, -125.92503  2022-05-25/2023-04-26
#
#                       dp_list
# 0  2023-03-14T15:55:57.922767
# 1  2024-01-09T22:53:53.192781
# 2  2023-12-05T06:23:13.414755
# 3  2024-02-11T01:21:47.832449
# 4  2023-05-16T20:06:51.177217
# 5  2023-06-09T21:58:39.062861
# 6  2023-03-14T16:03:01.039560
# 7  2024-01-09T23:09:29.611338
# 8  2023-12-05T06:29:23.231319
# 9  2024-02-11T00:53:55.913757

# %%
df['WKT'] = df['geom_list'].apply(to_wkt)

# %%
df.head()
# Out:
#                                                   id  \
# 0  https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1  https://catalogue.cioos.ca/dataset/00347450-75...
# 2  https://catalogue.cioos.ca/dataset/00347450-75...
# 3  https://catalogue.cioos.ca/dataset/00347450-75...
# 4  https://catalogue.cioos.ca/dataset/003ead14-1f...
#
#                     type_list  \
# 0  https://schema.org/Dataset
# 1  https://schema.org/Dataset
# 2  https://schema.org/Dataset
# 3  https://schema.org/Dataset
# 4  https://schema.org/Dataset
#
#                                            name_list  \
# 0  Boundary Pass Conductivity Temperature Depth D...
# 1  Strait of Georgia East Capteur d'Oxygène déplo...
# 2  Strait of Georgia East Oxygen Sensor Deployed ...
# 3  Strait of Georgia East Capteur d'Oxygène déplo...
# 4  Patricia Bay Conductivité/Température/Profonde...
#
#                                              kw_list  \
# 0  speed_of_sound_in_sea_water, Subsurfacesalinit...
# 1  Oxygen, Subsurface temperature, volume_fractio...
# 2  Oxygène, Oceans, sea_water_temperature, Tempér...
# 3  Subsurface temperature, volume_fraction_of_oxy...
# 4  speed_of_sound_in_sea_water, Subsurfacesalinit...
#
#                                                b_URL  \
# 0  https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1  https://catalogue.cioos.ca/dataset/00347450-75...
# 2  https://catalogue.cioos.ca/dataset/00347450-75...
# 3  https://catalogue.cioos.ca/dataset/00347450-75...
# 4  https://catalogue.cioos.ca/dataset/003ead14-1f...
#
#                                               b_desc b_headline  \
# 0  The Sea-Bird Microcat SBE37SMP-ODO 9536 was de...       None
# 1  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 2  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 3  The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 4  The Sea-Bird SeaCAT SBE16plus V2 6536 was depl...       None
#
#                                            geom_list                tc_list  \
# 0    48.7662667 -123.0393167 48.7662667 -123.0393167  2018-10-26/2019-05-19
# 1                         -123.31687331, 49.04314848  2020-03-06/2020-09-24
# 2                         49.04314848, -123.31687331  2020-03-06/2020-09-24
# 3                         -123.31687331, 49.04314848  2020-03-06/2020-09-24
# 4  48.65136 -123.4864183333 48.65136 -123.4864183333  2011-10-02/2012-02-23
#
#                       dp_list  \
# 0  2023-03-14T15:55:57.922767
# 1  2024-01-09T22:53:53.192781
# 2  2023-12-05T06:23:13.414755
# 3  2024-02-11T01:21:47.832449
# 4  2023-05-16T20:06:51.177217
#
#                                                  WKT
# 0  POLYGON ((48.7662667 -123.0393167 48.7662667 -...
# 1             POLYGON ((-123.31687331, 49.04314848))
# 2             POLYGON ((49.04314848, -123.31687331))
# 3             POLYGON ((-123.31687331, 49.04314848))
# 4  POLYGON ((48.65136 -123.4864183333 48.65136 -1...

# %%
df.to_parquet('./output/temp.parquet') # needs to be done before geometry conversion/column add

# %%
def load_wkt(row):
    try:
        return wkt.loads(row)
    except Exception:
        return None

# %%
df['geometry'] = df['WKT'].apply(load_wkt)
# Out:
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: Points of LinearRing do not form a closed linestring
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: Points of LinearRing do not form a closed linestring
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: Points of LinearRing do not form a closed linestring
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: Points of LinearRing do not form a closed linestring
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ...
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: Points of LinearRing do not form a closed linestring
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered word: '{'type':'
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered word: '{'type':'
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# ParseException: Expected number but encountered ','
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IllegalArgumentException: point array must contain 0 or >1 elements
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# %%
gdf
# Out:
#                                                       id  \
# 0      https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1      https://catalogue.cioos.ca/dataset/00347450-75...
# 2      https://catalogue.cioos.ca/dataset/00347450-75...
# 3      https://catalogue.cioos.ca/dataset/00347450-75...
# 4      https://catalogue.cioos.ca/dataset/003ead14-1f...
# ...                                                  ...
# 12158  https://raw.githubusercontent.com/iodepo/odis-...
# 12159  https://raw.githubusercontent.com/iodepo/odis-...
# 12160  https://raw.githubusercontent.com/iodepo/odis-...
# 12161  https://raw.githubusercontent.com/iodepo/odis-...
# 12162  https://raw.githubusercontent.com/iodepo/odis-...
#
#                         type_list  \
# 0      https://schema.org/Dataset
# 1      https://schema.org/Dataset
# 2      https://schema.org/Dataset
# 3      https://schema.org/Dataset
# 4      https://schema.org/Dataset
# ...                           ...
# 12158  https://schema.org/Dataset
# 12159  https://schema.org/Dataset
# 12160  https://schema.org/Dataset
# 12161  https://schema.org/Dataset
# 12162  https://schema.org/Dataset
#
#                                                name_list  \
# 0      Boundary Pass Conductivity Temperature Depth D...
# 1      Strait of Georgia East Capteur d'Oxygène déplo...
# 2      Strait of Georgia East Oxygen Sensor Deployed ...
# 3      Strait of Georgia East Capteur d'Oxygène déplo...
# 4      Patricia Bay Conductivité/Température/Profonde...
# ...                                                  ...
# 12158  World Ocean Database - Multi-cast file: 2019/w...
# 12159  World Ocean Database - Multi-cast file: 2020/w...
# 12160  World Ocean Database - Multi-cast file: 2021/w...
# 12161  World Ocean Database - Multi-cast file: 2022/w...
# 12162  World Ocean Database - Multi-cast file: 2023/w...
#
#                                                  kw_list  \
# 0      speed_of_sound_in_sea_water, Subsurfacesalinit...
# 1      Oxygen, Subsurface temperature, volume_fractio...
# 2      Oxygène, Oceans, sea_water_temperature, Tempér...
# 3      Subsurface temperature, volume_fraction_of_oxy...
# 4      speed_of_sound_in_sea_water, Subsurfacesalinit...
# ...                                                  ...
# 12158                                               None
# 12159                                               None
# 12160                                               None
# 12161                                               None
# 12162                                               None
#
#                                                    b_URL  \
# 0      https://catalogue.cioos.ca/dataset/0007ee4e-0c...
# 1      https://catalogue.cioos.ca/dataset/00347450-75...
# 2      https://catalogue.cioos.ca/dataset/00347450-75...
# 3      https://catalogue.cioos.ca/dataset/00347450-75...
# 4      https://catalogue.cioos.ca/dataset/003ead14-1f...
# ...                                                  ...
# 12158             https://noaa-wod-pds.s3.amazonaws.com/
# 12159             https://noaa-wod-pds.s3.amazonaws.com/
# 12160             https://noaa-wod-pds.s3.amazonaws.com/
# 12161             https://noaa-wod-pds.s3.amazonaws.com/
# 12162             https://noaa-wod-pds.s3.amazonaws.com/
#
#                                                   b_desc b_headline  \
# 0      The Sea-Bird Microcat SBE37SMP-ODO 9536 was de...       None
# 1      The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 2      The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 3      The Sea-Bird SBE 63 Dissolved Oxygen Sensor 63...       None
# 4      The Sea-Bird SeaCAT SBE16plus V2 6536 was depl...       None
# ...                                                  ...        ...
# 12158  Data for multiple casts from the World Ocean D...       None
# 12159  Data for multiple casts from the World Ocean D...       None
# 12160  Data for multiple casts from the World Ocean D...       None
# 12161  Data for multiple casts from the World Ocean D...       None
# 12162  Data for multiple casts from the World Ocean D...       None
#
#                                                geom_list  \
# 0        48.7662667 -123.0393167 48.7662667 -123.0393167
# 1                             -123.31687331, 49.04314848
# 2                             49.04314848, -123.31687331
# 3                             -123.31687331, 49.04314848
# 4      48.65136 -123.4864183333 48.65136 -123.4864183333
# ...                                                  ...
# 12158  31.332000732421875 -68.84600067138672 19.26699...
# 12159  31.131000518798828 -66.23729705810547 27.20498...
# 12160  -180.0 -70.05599975585938 180.0 64.36199951171875
# 12161  31.33099937438965 -70.18099975585938 25.157012...
# 12162  38.49599838256836 -66.57890319824219 16.760009...
#
#                      tc_list                     dp_list  \
# 0      2018-10-26/2019-05-19  2023-03-14T15:55:57.922767
# 1      2020-03-06/2020-09-24  2024-01-09T22:53:53.192781
# 2      2020-03-06/2020-09-24  2023-12-05T06:23:13.414755
# 3      2020-03-06/2020-09-24  2024-02-11T01:21:47.832449
# 4      2011-10-02/2012-02-23  2023-05-16T20:06:51.177217
# ...                      ...                         ...
# 12158                   None                        None
# 12159                   None                        None
# 12160                   None                        None
# 12161                   None                        None
# 12162                   None                        None
#
#                                                      WKT geometry
# 0      POLYGON ((48.7662667 -123.0393167 48.7662667 -...     None
# 1                 POLYGON ((-123.31687331, 49.04314848))     None
# 2                 POLYGON ((49.04314848, -123.31687331))     None
# 3                 POLYGON ((-123.31687331, 49.04314848))     None
# 4      POLYGON ((48.65136 -123.4864183333 48.65136 -1...     None
# ...                                                  ...      ...
# 12158  POLYGON ((31.332000732421875 -68.8460006713867...     None
# 12159  POLYGON ((31.131000518798828 -66.2372970581054...     None
# 12160  POLYGON ((-180.0 -70.05599975585938 180.0 64.3...     None
# 12161  POLYGON ((31.33099937438965 -70.18099975585938...     None
# 12162  POLYGON ((38.49599838256836 -66.57890319824219...     None
#
# [12163 rows x 12 columns]

# %%
i = 0
gdf_row_geojson = gdf.iloc[i:i + 1].geometry.to_json()
print(gdf_row_geojson)
# Out:
# {"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {}, "geometry": null, "bbox": null}], "bbox": [NaN, NaN, NaN, NaN]}
# /home/fils/.local/lib/python3.10/site-packages/geopandas/array.py:918: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 0]),  # minx
# /home/fils/.local/lib/python3.10/site-packages/geopandas/array.py:919: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(b[:, 1]),  # miny
# /home/fils/.local/lib/python3.10/site-packages/geopandas/array.py:920: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 2]),  # maxx
# /home/fils/.local/lib/python3.10/site-packages/geopandas/array.py:921: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(b[:, 3]),  # maxy
