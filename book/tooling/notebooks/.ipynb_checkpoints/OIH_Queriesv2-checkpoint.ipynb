# %% [markdown]
# # OIH Queries
#
# What follows are some example SPARQL queries used in OIH for the test interface

# %% [markdown]
# ## Setup and inits

# %% [markdown]
# ### Installs

# %%
# %%capture
#@title
# !pip install -q SPARQLWrapper
# !pip install -q cython
# !pip install -q cartopy
# !pip install -q geopandas
# !pip install -q contextily==1.0rc2
# !pip install -q pyshacl
# !pip install -q 'PyLD>=2.0.3'
# !pip install -q flatten_json
# !pip install -q 'fsspec>=0.3.3'
# !pip install -q s3fs
# !pip -q install SPARQLWrapper
# !pip install -q boto3
# !pip install -q kglab

# %% [markdown]
# ### Imports

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import dask, boto3
import dask.dataframe as dd
import numpy as np
import json
import geopandas
import matplotlib.pyplot as plt
import shapely
# import kglab as kg

oih = "https://graph.collaborium.io/blazegraph/namespace/oih/sparql"
oihdev = "https://graph.collaborium.io/blazegraph/namespace/development/sparql"
oihad = "https://graph.collaborium.io/blazegraph/namespace/aquadocs/sparql"

# %% [markdown]
# ### Support Functions

# %%
#@title
def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# ## Queries
#
# What follows is a set of queries designed to provide a feel for the OIH graph

# %% [markdown]
# ### Simple Count
#
# How many triples are there?

# %%
rq_count = """SELECT (COUNT(*) as ?Triples) 
WHERE 
  {
      { ?s ?p ?o } 
  }
"""

# %%
dfsc = get_sparql_dataframe(oihdev, rq_count)
dfsc.head()
# Out:
#    Triples
# 0  3004791

# %% [markdown]
# ## Simple org list

# %%
rq_orgs = """SELECT (COUNT(*) as ?Triples) 
WHERE 
  {
      { ?s ?p ?o } 
  }
"""

# %%
dfsc = get_sparql_dataframe(oihdev, rq_orgs)
dfsc.head()
# Out:
#    Triples
# 0  3004791

# %% [markdown]
# ### Predicate Counts
#
# This gives an overview of unique predicates that connect a subject to an object.  This gives us both an idea of the properties we are using on things and count of their usage.

# %%
rq_pcount = """SELECT ?p (COUNT(?p) as ?pCount)
WHERE
{
  # ?s ?p ?o .
}
GROUP BY ?p
"""

# %%
dfc = get_sparql_dataframe(oihdev, rq_pcount)
dfc['pCount'] = dfc["pCount"].astype(int) # convert count to int
# dfc.set_index('p', inplace=True)

# %%
dfc_sorted = dfc.sort_values('pCount', ascending=False)
dfc_sorted.head(10)
# Out:
#                                                   p  pCount
# 56  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  717060
# 8                       https://schema.org/keywords  398084
# 2                           https://schema.org/name  336036
# 4                            https://schema.org/url  181943
# 5                         https://schema.org/author  157359
# 0                    https://schema.org/description  134582
# 10               https://schema.org/itemListElement   79652
# 1                     https://schema.org/identifier   78923
# 48                    https://schema.org/knowsAbout   67752
# 19                  http://www.w3.org/ns/prov#value   66670

# %%
rcount = len(dfc_sorted)
print(rcount)
# Out:
# 58

# %%
ts = dfc_sorted.tail(38)['pCount'].sum()
print(ts)
# Out:
# 357165

# %%
hs = dfc_sorted.head(10)
hs.append({'p':'Other','pCount':ts}, ignore_index=True) 
hs.set_index('p', inplace=True)
hs.head(10)
# Out:
#                                                  pCount
# p
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type  717060
# https://schema.org/keywords                      398084
# https://schema.org/name                          336036
# https://schema.org/url                           181943
# https://schema.org/author                        157359
# https://schema.org/description                   134582
# https://schema.org/itemListElement                79652
# https://schema.org/identifier                     78923
# https://schema.org/knowsAbout                     67752
# http://www.w3.org/ns/prov#value                   66670

# %%
plot = hs.plot.pie(y='pCount',x='p',legend=False, figsize=(10, 10))

# %% [markdown]
# ### OIH Base Query

# %%
rq_main = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

        SELECT DISTINCT ?g  ?s   ?type ?score ?name ?url ?lit ?description ?headline
        WHERE
        {
           # ?lit bds:search "coral" .
           # ?lit bds:matchAllTerms "false" .
           # ?lit bds:relevance ?score .
           graph ?g {
            # ?s ?p ?lit .
            # ?s rdf:type ?type . 
            OPTIONAL { ?s schema:name ?name .   }
            OPTIONAL { ?s schema:headline ?headline .   }
            OPTIONAL { ?s schema:url ?url .   }
            OPTIONAL { ?s schema:description ?description .    }
          }

        }
        ORDER BY DESC(?score)
        LIMIT 30
        OFFSET 0
        """

# %%
df = get_sparql_dataframe(oihdev, rq_main)
df.head(5)
# Out:
#                                                    g  \
# 0  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
# 1  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
# 2  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
# 3  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
# 4  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
#
#                              s                             type score  \
# 0  oai:aquadocs.org:1834/35000  https://schema.org/CreativeWork   1.0
# 1   oai:aquadocs.org:1834/2013  https://schema.org/CreativeWork   1.0
# 2  oai:aquadocs.org:1834/20117  https://schema.org/CreativeWork   1.0
# 3   oai:aquadocs.org:1834/3262  https://schema.org/CreativeWork   1.0
# 4   oai:aquadocs.org:1834/7130  https://schema.org/CreativeWork   1.0
#
#                                                 name  \
# 0              Promising marine species for hatchery
# 1  Interacciones entre corales y macroalgas: depe...
# 2  M/V CONNECTED Coral Reef Restoration Monitorin...
# 3  Los corales (Anthozoa e Hidrozoa) de la bahÃ­a...
# 4  Informe TÃ©cnico AMERB NÂº 087/2014. EvaluaciÃ...
#
#                                            url    lit  \
# 0  https://www.oceandocs.org/handle/1834/35000  Coral
# 1   https://www.oceandocs.org/handle/1834/2013  Coral
# 2  https://www.oceandocs.org/handle/1834/20117  Coral
# 3   https://www.oceandocs.org/handle/1834/3262  Coral
# 4   https://www.oceandocs.org/handle/1834/7130  Coral
#
#                                          description headline
# 0                                                        None
# 1   - Macroalgae proliferation on coral reefs has...     None
# 2   - This document presents the results of the m...     None
# 3   - En el presente trabajo se describe las form...     None
# 4   - Los informes tÃ©cnicos son la respuesta adm...     None

# %% [markdown]
# ### OIH Gleaner Query

# %%
rq_maingl = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

        SELECT DISTINCT ?g  ?s  ?wat ?orgname ?domain ?type ?score ?name ?url ?lit ?description ?headline
        WHERE
        {
           # ?lit bds:search "coral" .
           # ?lit bds:matchAllTerms "false" .
           # ?lit bds:relevance ?score .
           graph ?g {
            # ?s ?p ?lit .
            # ?s rdf:type ?type . 
            OPTIONAL { ?s schema:name ?name .   }
            OPTIONAL { ?s schema:headline ?headline .   }
            OPTIONAL { ?s schema:url ?url .   }
            OPTIONAL { ?s schema:description ?description .    }
          }
           # ?sp prov:generated ?g  .
           # ?sp prov:used ?used .
           # ?used prov:hadMember ?hm .
           # ?hm prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        ORDER BY DESC(?score)
        LIMIT 30
        OFFSET 0
        """

# %%
df = get_sparql_dataframe(oihdev, rq_maingl)
df.head(5)
# Out:
#                                                    g  \
# 0  urn:gleaner:summoned:aquadocs:5d5193e7e253bbb1...
# 1  urn:gleaner:milled:obis:18d1180a74c200d06f9114...
# 2  urn:gleaner:milled:obis:24bac898cda34444176ec4...
# 3  urn:gleaner:milled:obis:24d453e3a4ea6d1f117e5c...
# 4  urn:gleaner:milled:obis:2bf98aa888d856b8706176...
#
#                              s                                          wat  \
# 0  oai:aquadocs.org:1834/18666  https://www.re3data.org/repository/aquadocs
# 1                      t416560      https://www.re3data.org/repository/obis
# 2                      t419335      https://www.re3data.org/repository/obis
# 3                      t419362      https://www.re3data.org/repository/obis
# 4                      t420960      https://www.re3data.org/repository/obis
#
#                                  orgname                domain  \
# 0                               AquaDocs  https://aquadocs.org
# 1  Ocean Biodiversity Information System      https://obis.org
# 2  Ocean Biodiversity Information System      https://obis.org
# 3  Ocean Biodiversity Information System      https://obis.org
# 4  Ocean Biodiversity Information System      https://obis.org
#
#                               type score  \
# 0  https://schema.org/CreativeWork   1.0
# 1       https://schema.org/Dataset   1.0
# 2       https://schema.org/Dataset   1.0
# 3       https://schema.org/Dataset   1.0
# 4       https://schema.org/Dataset   1.0
#
#                                                 name  \
# 0  Observations on Florida reef corals treated wi...
# 1  Coral Reef Evaluation and Monitoring Project D...
# 2  Coral Reef Evaluation and Monitoring Project F...
# 3  Coral Reef Evaluation and Monitoring Project F...
# 4  Coral Reef Evaluation and Monitoring Project F...
#
#                                                  url    lit  \
# 0        https://www.oceandocs.org/handle/1834/18666  coral
# 1  https://obis.org/dataset/46005357-02b8-4f17-b0...  coral
# 2  https://obis.org/dataset/d4ec17b8-fc96-49b9-b7...  coral
# 3  https://obis.org/dataset/36bca81c-6d77-4fd4-a9...  coral
# 4  https://obis.org/dataset/431f96f7-521c-4182-ae...  coral
#
#                                          description headline
# 0                                       - (24pp.) -      None
# 1  The purpose of the Coral Reef Evaluation and M...     None
# 2  The purpose of the Coral Reef Evaluation and M...     None
# 3  The purpose of the Coral Reef Evaluation and M...     None
# 4  The purpose of the Coral Reef Evaluation and M...     None

# %% [markdown]
# ## Query for prov
#
# Count (count(distinct ?tag) as ?count)
#
# Need to look for the date in the prov record too.  I keep it by day granularity, so I should be able to see the difference if I focos on a specific repo or look over the dates

# %%
rq_prov = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

       SELECT   ( COUNT(?hm) as ?count) ?wat  ?orgname ?domain
        WHERE
        {
           # ?hm prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        GROUP BY ?wat ?orgname ?domain
        """

# %%
rq_prov2 = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

        SELECT ( COUNT(?s) as ?count) ?wat  ?orgname ?domain
        WHERE
        {
           graph ?g {
             VALUES (?type) { ( schema:CreativeWork ) ( schema:Map )  ( schema:Person )  ( schema:Organization )  ( schema:Dataset )  ( schema:Course ) } 
            # ?s rdf:type ?type . 
            OPTIONAL { ?s schema:name ?name .   }
            OPTIONAL { ?s schema:headline ?headline .   }
            OPTIONAL { ?s schema:url ?url .   }
            OPTIONAL { ?s schema:description ?description .    }
          }
           # ?sp prov:generated ?g  .
           # ?sp prov:used ?used .
           # ?used prov:hadMember ?hm .
           # ?hm prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
                GROUP BY ?wat ?orgname ?domain

        """

# %%
dfp = get_sparql_dataframe(oihdev, rq_prov2)
dfp['count'] = dfp["count"].astype(int) # convert count c to int
dfp.set_index('orgname', inplace=True)
dfp.head(10)
# Out:
#                                                 count  \
# orgname
# Ocean Best Practices                             8562
# Marine Training EU                                937
# Ocean Biodiversity Information System            9140
# AquaDocs                                        75465
# OceanExpert UNESCO/IOC Project Office for IODE  44455
#
#                                                                                               wat  \
# orgname
# Ocean Best Practices                                      https://www.re3data.org/repository/obps
# Marine Training EU                              https://www.re3data.org/repository/marinetraining
# Ocean Biodiversity Information System                     https://www.re3data.org/repository/obis
# AquaDocs                                              https://www.re3data.org/repository/aquadocs
# OceanExpert UNESCO/IOC Project Office for IODE     https://www.re3data.org/repository/oceanexpert
#
#                                                                             domain
# orgname
# Ocean Best Practices                            https://oih.oceanbestpractices.org
# Marine Training EU                                      https://marinetraining.eu/
# Ocean Biodiversity Information System                             https://obis.org
# AquaDocs                                                      https://aquadocs.org
# OceanExpert UNESCO/IOC Project Office for IODE            https://oceanexpert.org/

# %%
plot = dfp.plot.pie(y='count',legend=False, figsize=(10, 10))

# %%
rq_provdate = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

 
       SELECT   ( COUNT(?s) as ?count) ?time ?orgname  
        WHERE
        {
           # ?s a prov:Activity  .
           # ?s prov:endedAtTime ?time .
           # ?s prov:generated ?gen .
           # ?s prov:used ?used .
           # ?used prov:hadMember ?mem .
           # ?mem prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        GROUP BY ?time ?orgname  
        """

# %%
dfpd = get_sparql_dataframe(oihdev, rq_provdate)
dfpd.head(10)
# Out:
#    count                      time  \
# 0    313  2021-09-25T00:00:00.000Z
# 1      1  2021-09-25T00:00:00.000Z
# 2   4249  2021-09-25T00:00:00.000Z
# 3  28771  2021-09-25T00:00:00.000Z
# 4      1  2021-09-25T00:00:00.000Z
#
#                                           orgname
# 0                              Marine Training EU
# 1                            Ocean Best Practices
# 2           Ocean Biodiversity Information System
# 3  OceanExpert UNESCO/IOC Project Office for IODE
# 4                                        AquaDocs

# %%
dfpd = get_sparql_dataframe(oihdev, rq_provdate)
dfpd['count'] = dfpd["count"].astype(int) # convert count c to int
dfpd.set_index('time', inplace=True)
dfpd.head()
# Out:
#                           count  \
# time
# 2021-09-25T00:00:00.000Z    313
# 2021-09-25T00:00:00.000Z      1
# 2021-09-25T00:00:00.000Z   4249
# 2021-09-25T00:00:00.000Z  28771
# 2021-09-25T00:00:00.000Z      1
#
#                                                                  orgname
# time
# 2021-09-25T00:00:00.000Z                              Marine Training EU
# 2021-09-25T00:00:00.000Z                            Ocean Best Practices
# 2021-09-25T00:00:00.000Z           Ocean Biodiversity Information System
# 2021-09-25T00:00:00.000Z  OceanExpert UNESCO/IOC Project Office for IODE
# 2021-09-25T00:00:00.000Z                                        AquaDocs

# %%
ax = dfpd.plot.bar(rot=80, stacked=True, figsize=(15, 5))

# %% [markdown]
# ## Feed query
#
# Goal here is see if the prov will give us the elements for an RSS feed.
# The [RSS specs](https://validator.w3.org/feed/docs/rss2.html) give us the elements we need to populate.  Focus on; title(name), date, author, description
#
# * Element 	Description 	Example
# * title 	The title of the item. 	Venice Film Festival Tries to Quit Sinking
# * link 	The URL of the item. 	http://www.nytimes.com/2002/09/07/movies/07FEST.html
# * description 	The item synopsis. 	Some of the most heated chatter at the Venice Film Festival this week was about the way that the arrival of the stars at the Palazzo del Cinema was being staged.
# * author 	Email address of the author of the item. More. 	oprah@oxygen.net
# * category 	Includes the item in one or more categories. More. 	Simpsons Characters
# * comments 	URL of a page for comments relating to the item. More. 	http://www.myblog.org/cgi-local/mt/mt-comments.cgi?entry_id=290
# * enclosure 	Describes a media object that is attached to the item. More. 	<enclosure url="http://live.curry.com/mp3/celebritySCms.mp3" length="1069871" type="audio/mpeg"/>
# * guid 	A string that uniquely identifies the item. More. 	<guid isPermaLink="true">http://inessential.com/2002/09/01.php#a2</guid>
# * pubDate 	Indicates when the item was published. More. 	Sun, 19 May 2002 15:21:36 GMT
# * source 	The RSS channel that the item came from. More. 	<source url="http://www.quotationspage.com/data/qotd.rss">Quotes of the Day</source>

# %%
rq_provdatelist = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

       SELECT  ?time ?orgname ?memval  ?memname ?memdesc
        WHERE
        {
           # ?s a prov:Activity  .
           # ?s prov:endedAtTime ?time .
           # ?s prov:generated ?gen .
           # ?s prov:used ?used .
           # ?used prov:hadMember ?mem .
           # ?mem prov:value ?memval .
           # ?mem schema:name ?memname .
           # ?mem schema:description ?memdesc .
           # ?mem prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        ORDER BY DESC(?time)
        LIMIT 1000

        """

# %%
dfpl = get_sparql_dataframe(oihdev, rq_provdatelist)
dfpl.head(10)
# Out:
#                        time             orgname  \
# 0  2021-09-25T00:00:00.000Z  Marine Training EU
# 1  2021-09-25T00:00:00.000Z  Marine Training EU
# 2  2021-09-25T00:00:00.000Z  Marine Training EU
# 3  2021-09-25T00:00:00.000Z  Marine Training EU
# 4  2021-09-25T00:00:00.000Z  Marine Training EU
# 5  2021-09-25T00:00:00.000Z  Marine Training EU
# 6  2021-09-25T00:00:00.000Z  Marine Training EU
# 7  2021-09-25T00:00:00.000Z  Marine Training EU
# 8  2021-09-25T00:00:00.000Z  Marine Training EU
# 9  2021-09-25T00:00:00.000Z  Marine Training EU
#
#                                     memval  \
# 0  https://www.marinetraining.eu/node/4349
# 1  https://www.marinetraining.eu/node/4389
# 2  https://www.marinetraining.eu/node/4159
# 3  https://www.marinetraining.eu/node/3908
# 4  https://www.marinetraining.eu/node/4345
# 5  https://www.marinetraining.eu/node/4330
# 6  https://www.marinetraining.eu/node/4323
# 7  https://www.marinetraining.eu/node/3877
# 8  https://www.marinetraining.eu/node/3958
# 9  https://www.marinetraining.eu/node/4326
#
#                                              memname  \
# 0     Shipping and Offshore Activities in the Arctic
# 1                     Methods of Scientific Research
# 2  Diseases and Veterinary Aspects Related to Aqu...
# 3                              Navigation Technology
# 4                       Qualitative Research Methods
# 5                  Icelandic Society and Environment
# 6                               Fisheries in Iceland
# 7                   Basal and Comparative Immunology
# 8                              Evolutionary Genetics
# 9         Physical Processes of Coastal Environments
#
#                                              memdesc
# 0  Course Description:\n\nThe reduction of Arctic...
# 1  Course Description:\n\nThe course covers the p...
# 2  General course objectives\n\nThe student will ...
# 3  Course content\n\nRadio technology\n\n\n\tAnte...
# 4  Course Description:\n\nThe course is designed ...
# 5  Course Description:\n\nThe course explores the...
# 6  Course Description:\n\nIn this course the lear...
# 7  Course content\n\nThis course aims to provide ...
# 8  Evolution is one of the central, unifying theo...
# 9  Course Description:\n\nThe course focuses on o...

# %% [markdown]
# ## Types Breakdown

# %%
rq_types = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

 
       SELECT   ( COUNT(?type) as ?count) ?type   
        WHERE
        {
        
           # ?s rdf:type ?type
           FILTER ( ?type IN (schema:ResearchProject, schema:Project, schema:Organization, schema:Dataset, schema:CreativeWork, schema:Person, schema:Map, schema:Course, schema:CourseInstance, schema:Event, schema:Vehicle) )

        }
        GROUP BY ?type  
        ORDER BY DESC(?count)
        """

# %%
dft = get_sparql_dataframe(oihdev, rq_types)
dft['count'] = dft["count"].astype(int) # convert count c to int
dft.set_index('type', inplace=True)
dft.head(10)
# Out:
#                                     count
# type
# https://schema.org/Person          176409
# https://schema.org/CreativeWork     40539
# https://schema.org/Organization     30420
# https://schema.org/Event            20160
# https://schema.org/Dataset           4248
# https://schema.org/Course             822
# https://schema.org/CourseInstance     822

# %%
plot_t = dft.plot.pie(y='count',legend=False, figsize=(12, 12))

# %%
rq_typesCHECK = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

 
       SELECT   ( COUNT(*) as ?count)  
        WHERE
        {
        
           # ?s rdf:type schema:Project

        }
      
        """

# %%
dft = get_sparql_dataframe(oihdev, rq_typesCHECK)
dft['count'] = dft["count"].astype(int) # convert count c to int
# dft.set_index('type', inplace=True)
dft.head(10)
# Out:
#    count
# 0      0
