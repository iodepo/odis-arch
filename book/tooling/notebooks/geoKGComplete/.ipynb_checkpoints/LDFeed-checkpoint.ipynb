# %% [markdown]
# # Marine Regions LD Feed
#
# Exploring working with the data from these commands
#
# ## Current thoughts
#
# * Getting the data graph is a simple call and then we can frame it and use similar methods to get our URL set.
# * At that point it's the classic Gleaner workflow, no changes seen.
# * As we get new feed updatges we can leverage the prov graph generated by Gleaner combined with the feed time stamps (nothing hard there)
# * This is a nice way to maintain updates in the OIH graph vs the prov pattern (complements likely, not replaces)|
# * put the feed URL in the robots.txt?
#
# ## Data graphs via curl
#
# ```bash
# curl -L --url http://marineregions.org/mrgid/2795.jsonld
# curl -L --url http://marineregions.org/mrgid/2795 -H Accept:application/ld+json
# curl -L --url http://marineregions.org/feed -HAccept:application/ld+json
# ```
#
# ## refs:
#
# - [LDF](linkdatafragments.org)
# - [LDES specification](https://w3id.org/ldes/specification)
# - [TREE](https://treecg.github.io/specification/) and the [TREEcg repo](https://github.com/TREEcg/specification)

# %% [markdown]
# ## my installs and imports..
#
# many not used..  I just lazy copied in some I use for other work..  didn't prun down to just the set used here..   which is likely just pyLD

# %%
# !pip install -q 'PyLD>=2.0.3'

# %%
from pyld import jsonld

# %% [markdown]
# ## Problems
#
# In the following, if I frame with "framenc", I get results like:
#
# ```json
# {
#             "@id": "mrgid/103?t=1626519699",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/103"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:39Z"
#             }
#         },
# ```
#
# which lack the fulled express domain name based @id values.  I was hoping to get results with a full qualified domain name from the frame and then I would simply place that into a native Go struct that I could pass along to my regular indexing code without changes.
#
# If I use "frame" which should be the full context.  I get an error "list index out of range"
#
# Also, why does the context contain both
#
# *       "dcterms": "http://purl.org/dc/terms/",
# *       "dct": "http://purl.org/dc/terms//dup/",
#
# Both are used in the data graph..   when I tried to align them though, I got some other errors..  likely I had an error in the context.

# %%
docurl = "http://marineregions.org/feed.jsonld"

# with open('./data/mregFeedv2.json', 'rb') as f:
#     doc = f.read()

# this is not used..   had it for when playing with compact and expand
context =  {
      "tree": "https://w3id.org/tree#",
      "ldes": "https://w3id.org/ldes#",
      "ldes:versionKey": {
        "@type": "@id",
        "@container": "@list"
      },
      "dcterms": "http://purl.org/dc/terms/",
      "dcterms:isVersionOf": {
        "@type": "@id"
      },
      "dcterms:modified": {
        "@type": "xsd:dateTime"
      },
      "xsd": "http://www.w3.org/2001/XMLSchema#",
      "sh": "http://www.w3.org/ns/shacl#",
      "schema": "https://schema.org/",
      "skos": "http://www.w3.org/2004/02/skos/core#",
      "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
      "mr": "http://marineregions.org/ns/ontology#",
      "dct": "http://purl.org/dc/terms//dup/",
      "gsp": "http://www.opengis.net/ont/geosparql#",
      "dcat": "http://www.w3.org/ns/dcat#"
    }

frame = {
  "@context": {
      "tree": "https://w3id.org/tree#",
      "ldes": "https://w3id.org/ldes#",
      "ldes:versionKey": {
        "@type": "@id",
        "@container": "@list"
      },
      "dcterms": "http://purl.org/dc/terms/",
      "dcterms:isVersionOf": {
        "@type": "@id"
      },
      "dcterms:modified": {
        "@type": "xsd:dateTime"
      },
      "xsd": "http://www.w3.org/2001/XMLSchema#",
      "sh": "http://www.w3.org/ns/shacl#",
      "schema": "https://schema.org/",
      "skos": "http://www.w3.org/2004/02/skos/core#",
      "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
      "mr": "http://marineregions.org/ns/ontology#",
      "dct": "http://purl.org/dc/terms//dup/",
      "gsp": "http://www.opengis.net/ont/geosparql#",
      "dcat": "http://www.w3.org/ns/dcat#"
    },
  "@explicit": "true",
  "dcterms:isVersionOf": "",
  "dcterms:modified": ""
}

framenc = {
  "@context": {"schema": "https://schema.org/",
               "dcterms": "http://purl.org/dc/terms/"},
  "@explicit": "true",
  "dcterms:isVersionOf": "",
  "dcterms:modified": ""
}

# rg = jsonld.expand(doc, context)  # would ned to define context for this code
rg = jsonld.frame(docurl, frame)  ##  framenc: works..   but no FQDN.    frame:  gives errors

jd = json.dumps(rg, indent=4)
print(jd)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-36c35667fda8> in <module>
#      68
#      69 # rg = jsonld.expand(doc, context)  # would ned to define context for this code
# ---> 70 rg = jsonld.frame(docurl, frame)
#      71
#      72 jd = json.dumps(rg, indent=4)
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in frame(input_, frame, options)
#     212     :return: the framed JSON-LD output.
#     213     """
# --> 214     return JsonLdProcessor().frame(input_, frame, options)
#     215
#     216
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in frame(self, input_, frame, options)
#    1054
#    1055         # do framing
# -> 1056         framed = self._frame(expanded, expanded_frame, options)
#    1057
#    1058         # remove @preserve from results
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in _frame(self, input_, frame, options)
#    2865         # frame the subjects
#    2866         framed = []
# -> 2867         self._match_frame(
#    2868             state, sorted(state['subjects'].keys()), frame, framed, None)
#    2869
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in _match_frame(self, state, subjects, frame, parent, property)
#    3969
#    3970         # filter out subjects that match the frame
# -> 3971         matches = self._filter_subjects(state, subjects, frame, flags)
#    3972
#    3973         # add matches to output
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in _filter_subjects(self, state, subjects, frame, flags)
#    4285         for id_ in subjects:
#    4286             subject = state['graphMap'][state['graph']][id_]
# -> 4287             if self._filter_subject(state, subject, frame, flags):
#    4288                 rval[id_] = subject
#    4289         return rval
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in _filter_subject(self, state, subject, frame, flags)
#    4387                     elif _is_value(this_frame):
#    4388                         # match on any matching value
# -> 4389                         match_this = any(self._value_match(this_frame, nv) for nv in node_values)
#    4390                     elif _is_subject_reference(this_frame):
#    4391                         match_this = any(
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in <genexpr>(.0)
#    4387                     elif _is_value(this_frame):
#    4388                         # match on any matching value
# -> 4389                         match_this = any(self._value_match(this_frame, nv) for nv in node_values)
#    4390                     elif _is_subject_reference(this_frame):
#    4391                         match_this = any(
#
# /opt/conda/lib/python3.9/site-packages/pyld/jsonld.py in _value_match(self, pattern, value)
#    4505         if not v2 and not t2 and not l2:
#    4506             return True
# -> 4507         if not (v1 in v2 or _is_empty_object(v2[0])):
#    4508             return False
#    4509         if not ((not t1 and not t2) or (t1 in t2) or (t1 and t2 and _is_empty_object(t2[0]))):
#
# IndexError: list index out of range
