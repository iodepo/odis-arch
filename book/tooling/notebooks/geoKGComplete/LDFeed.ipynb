# %% [markdown]
# # Marine Regions LD Feed
#
# Exploring working with the data from these commands
#
# ## Current thoughts
#
# * Getting the data graph is a simple call and then we can frame it and use similar methods to get our URL set.
# * At that point it's the classic Gleaner workflow, no changes seen.
# * As we get new feed updatges we can leverage the prov graph generated by Gleaner combined with the feed time stamps (nothing hard there)
# * This is a nice way to maintain updates in the OIH graph vs the prov pattern (complements likely, not replaces)|
# * put the feed URL in the robots.txt?
#
# ## Data graphs via curl
#
# ```bash
# curl -L --url http://marineregions.org/mrgid/2795.jsonld
# curl -L --url http://marineregions.org/mrgid/2795 -H Accept:application/ld+json
# curl -L --url http://marineregions.org/feed -HAccept:application/ld+json
# ```
#
# ## refs:
#
# - [LDF](linkdatafragments.org)
# - [LDES specification](https://w3id.org/ldes/specification)
# - [TREE](https://treecg.github.io/specification/) and the [TREEcg repo](https://github.com/TREEcg/specification)

# %% [markdown]
# ## my installs and imports..

# %%
# !pip install -q 'PyLD>=2.0.3'

# %%
from pyld import jsonld
import json

# %% [markdown]
# ## Problems
#
# In the following, if I frame with "framenc", I get results like:
#
# ```json
# {
#             "@id": "mrgid/103?t=1626519699",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/103"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:39Z"
#             }
#         },
# ```
#
# which lack the fulled express domain name based @id values.  I was hoping to get results with a full qualified domain name from the frame and then I would simply place that into a native Go struct that I could pass along to my regular indexing code without changes.
#
# If I use "frame" which should be the full context.  I get an error "list index out of range"
#
# Also, why does the context contain both
#
# *       "dcterms": "http://purl.org/dc/terms/",
# *       "dct": "http://purl.org/dc/terms//dup/",
#
# Both are used in the data graph..   when I tried to align them though, I got some other errors..  likely I had an error in the context.

# %%
docurl = "http://marineregions.org/feed.jsonld"

# with open('./data/mregFeedv2.json', 'rb') as f:
#     doc = f.read()

# this is not used..   had it for when playing with compact and expand
context =  {
      "tree": "https://w3id.org/tree#",
      "ldes": "https://w3id.org/ldes#",
      "ldes:versionKey": {
        "@type": "@id",
        "@container": "@list"
      },
      "dcterms": "http://purl.org/dc/terms/",
      "dcterms:isVersionOf": {
        "@type": "@id"
      },
      "dcterms:modified": {
        "@type": "xsd:dateTime"
      },
      "xsd": "http://www.w3.org/2001/XMLSchema#",
      "sh": "http://www.w3.org/ns/shacl#",
      "schema": "https://schema.org/",
      "skos": "http://www.w3.org/2004/02/skos/core#",
      "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
      "mr": "http://marineregions.org/ns/ontology#",
      "dct": "http://purl.org/dc/terms//dup/",
      "gsp": "http://www.opengis.net/ont/geosparql#",
      "dcat": "http://www.w3.org/ns/dcat#"
    }

frame = {
  "@context": {
      "tree": "https://w3id.org/tree#",
      "ldes": "https://w3id.org/ldes#",
      "ldes:versionKey": {
        "@type": "@id",
        "@container": "@list"
      },
      "dcterms": "http://purl.org/dc/terms/",
      "dcterms:isVersionOf": {
        "@type": "@id"
      },
      "dcterms:modified": {
        "@type": "xsd:dateTime"
      },
      "xsd": "http://www.w3.org/2001/XMLSchema#",
      "sh": "http://www.w3.org/ns/shacl#",
      "schema": "https://schema.org/",
      "skos": "http://www.w3.org/2004/02/skos/core#",
      "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
      "mr": "http://marineregions.org/ns/ontology#",
      "dct": "http://purl.org/dc/terms//dup/",
      "gsp": "http://www.opengis.net/ont/geosparql#",
      "dcat": "http://www.w3.org/ns/dcat#"
    },
  "@explicit": "true",
  "dcterms:isVersionOf": "",
  "dcterms:modified": ""
}

framenc = {
  "@context": {"schema": "https://schema.org/",
               "dcterms": "http://purl.org/dc/terms/"},
  "@explicit": "true",
  "dcterms:isVersionOf": "",
  "dcterms:modified": ""
}

# rg = jsonld.expand(doc, context)  # would ned to define context for this code
rg = jsonld.frame(docurl, framenc)  ##  framenc: works..   but no FQDN.    frame:  gives errors

jd = json.dumps(rg, indent=4)
print(jd)
# Out:
# {
#     "@context": {
#         "schema": "https://schema.org/",
#         "dcterms": "http://purl.org/dc/terms/"
#     },
#     "@graph": [
#         {
#             "@id": "mrgid/1012?t=1626519765",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/1012"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:45Z"
#             }
#         },
#         {
#             "@id": "mrgid/1038?t=1626519844",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/1038"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/103?t=1626519699",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/103"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:39Z"
#             }
#         },
#         {
#             "@id": "mrgid/14642?t=1626519821",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/14642"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:41Z"
#             }
#         },
#         {
#             "@id": "mrgid/15293?t=1626519630",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/15293"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:30Z"
#             }
#         },
#         {
#             "@id": "mrgid/15525?t=1626519750",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/15525"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:30Z"
#             }
#         },
#         {
#             "@id": "mrgid/18069?t=1626519669",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/18069"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:09Z"
#             }
#         },
#         {
#             "@id": "mrgid/18081?t=1626519694",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/18081"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/18168?t=1626519725",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/18168"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:05Z"
#             }
#         },
#         {
#             "@id": "mrgid/19435?t=1626519623",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/19435"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:23Z"
#             }
#         },
#         {
#             "@id": "mrgid/21391?t=1626519607",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/21391"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:07Z"
#             }
#         },
#         {
#             "@id": "mrgid/21715?t=1626519685",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/21715"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:25Z"
#             }
#         },
#         {
#             "@id": "mrgid/21720?t=1626519818",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/21720"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:38Z"
#             }
#         },
#         {
#             "@id": "mrgid/21751?t=1626519819",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/21751"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:39Z"
#             }
#         },
#         {
#             "@id": "mrgid/24200?t=1626519660",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/24200"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:00Z"
#             }
#         },
#         {
#             "@id": "mrgid/24210?t=1626519832",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/24210"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:52Z"
#             }
#         },
#         {
#             "@id": "mrgid/24237?t=1626519824",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/24237"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:44Z"
#             }
#         },
#         {
#             "@id": "mrgid/2449?t=1626519712",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/2449"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:52Z"
#             }
#         },
#         {
#             "@id": "mrgid/2458?t=1626519605",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/2458"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:05Z"
#             }
#         },
#         {
#             "@id": "mrgid/25567?t=1626519734",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/25567"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/2671?t=1626519617",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/2671"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:17Z"
#             }
#         },
#         {
#             "@id": "mrgid/26865?t=1626519787",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/26865"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:07Z"
#             }
#         },
#         {
#             "@id": "mrgid/27017?t=1626519608",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27017"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:08Z"
#             }
#         },
#         {
#             "@id": "mrgid/27053?t=1626519669",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27053"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:09Z"
#             }
#         },
#         {
#             "@id": "mrgid/27095?t=1626519616",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27095"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:16Z"
#             }
#         },
#         {
#             "@id": "mrgid/27761?t=1626519663",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27761"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:03Z"
#             }
#         },
#         {
#             "@id": "mrgid/27849?t=1626519650",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27849"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:50Z"
#             }
#         },
#         {
#             "@id": "mrgid/27901?t=1626519719",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27901"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:59Z"
#             }
#         },
#         {
#             "@id": "mrgid/27935?t=1626519638",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27935"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:38Z"
#             }
#         },
#         {
#             "@id": "mrgid/27970?t=1626519684",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/27970"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:24Z"
#             }
#         },
#         {
#             "@id": "mrgid/28106?t=1626519729",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28106"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:09Z"
#             }
#         },
#         {
#             "@id": "mrgid/28260?t=1626519606",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28260"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:06Z"
#             }
#         },
#         {
#             "@id": "mrgid/28369?t=1626519847",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28369"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:07Z"
#             }
#         },
#         {
#             "@id": "mrgid/28444?t=1626519732",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28444"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:12Z"
#             }
#         },
#         {
#             "@id": "mrgid/28473?t=1626519642",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28473"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:42Z"
#             }
#         },
#         {
#             "@id": "mrgid/28482?t=1626519724",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28482"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/28884?t=1626519796",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/28884"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:16Z"
#             }
#         },
#         {
#             "@id": "mrgid/2905?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/2905"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/29079?t=1626519751",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29079"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:31Z"
#             }
#         },
#         {
#             "@id": "mrgid/29125?t=1626519837",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29125"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:57Z"
#             }
#         },
#         {
#             "@id": "mrgid/29128?t=1626519637",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29128"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:37Z"
#             }
#         },
#         {
#             "@id": "mrgid/29345?t=1626519730",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29345"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:10Z"
#             }
#         },
#         {
#             "@id": "mrgid/29412?t=1626519742",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29412"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:22Z"
#             }
#         },
#         {
#             "@id": "mrgid/29477?t=1626519708",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29477"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:48Z"
#             }
#         },
#         {
#             "@id": "mrgid/29685?t=1626519668",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/29685"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:08Z"
#             }
#         },
#         {
#             "@id": "mrgid/30319?t=1626519674",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/30319"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/30329?t=1626519750",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/30329"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:30Z"
#             }
#         },
#         {
#             "@id": "mrgid/3054?t=1626519682",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3054"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:22Z"
#             }
#         },
#         {
#             "@id": "mrgid/31190?t=1626519845",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/31190"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:05Z"
#             }
#         },
#         {
#             "@id": "mrgid/3240?t=1626519694",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3240"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/32653?t=1626519786",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/32653"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:06Z"
#             }
#         },
#         {
#             "@id": "mrgid/33276?t=1626519603",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/33276"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:03Z"
#             }
#         },
#         {
#             "@id": "mrgid/33305?t=1626519734",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/33305"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/3486?t=1626519635",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3486"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:35Z"
#             }
#         },
#         {
#             "@id": "mrgid/3611?t=1626519638",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3611"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:38Z"
#             }
#         },
#         {
#             "@id": "mrgid/36394?t=1626519763",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36394"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:43Z"
#             }
#         },
#         {
#             "@id": "mrgid/36420?t=1626519846",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36420"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:06Z"
#             }
#         },
#         {
#             "@id": "mrgid/36556?t=1626519845",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36556"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:05Z"
#             }
#         },
#         {
#             "@id": "mrgid/36652?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36652"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/36668?t=1626519662",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36668"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:02Z"
#             }
#         },
#         {
#             "@id": "mrgid/36686?t=1626519833",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36686"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:53Z"
#             }
#         },
#         {
#             "@id": "mrgid/36842?t=1626519783",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36842"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:03Z"
#             }
#         },
#         {
#             "@id": "mrgid/36858?t=1626519600",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36858"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:00Z"
#             }
#         },
#         {
#             "@id": "mrgid/36944?t=1626519753",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/36944"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/37598?t=1626519762",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/37598"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:42Z"
#             }
#         },
#         {
#             "@id": "mrgid/37784?t=1626519691",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/37784"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:31Z"
#             }
#         },
#         {
#             "@id": "mrgid/37871?t=1626519672",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/37871"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:12Z"
#             }
#         },
#         {
#             "@id": "mrgid/37938?t=1626519793",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/37938"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:13Z"
#             }
#         },
#         {
#             "@id": "mrgid/37993?t=1626519715",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/37993"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:55Z"
#             }
#         },
#         {
#             "@id": "mrgid/38103?t=1626519689",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38103"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:29Z"
#             }
#         },
#         {
#             "@id": "mrgid/3815?t=1626519752",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3815"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:32Z"
#             }
#         },
#         {
#             "@id": "mrgid/38227?t=1626519789",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38227"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:09Z"
#             }
#         },
#         {
#             "@id": "mrgid/38320?t=1626519774",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38320"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:54Z"
#             }
#         },
#         {
#             "@id": "mrgid/38360?t=1626519645",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38360"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:45Z"
#             }
#         },
#         {
#             "@id": "mrgid/38500?t=1626519683",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38500"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:23Z"
#             }
#         },
#         {
#             "@id": "mrgid/38517?t=1626519646",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38517"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:46Z"
#             }
#         },
#         {
#             "@id": "mrgid/38688?t=1626519794",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38688"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/3874?t=1626519837",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/3874"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:57Z"
#             }
#         },
#         {
#             "@id": "mrgid/38978?t=1626519828",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/38978"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:48Z"
#             }
#         },
#         {
#             "@id": "mrgid/39102?t=1626519820",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39102"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/39125?t=1626519805",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39125"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:25Z"
#             }
#         },
#         {
#             "@id": "mrgid/39175?t=1626519700",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39175"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/39185?t=1626519638",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39185"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:38Z"
#             }
#         },
#         {
#             "@id": "mrgid/39233?t=1626519773",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39233"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:53Z"
#             }
#         },
#         {
#             "@id": "mrgid/39362?t=1626519677",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39362"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:17Z"
#             }
#         },
#         {
#             "@id": "mrgid/39375?t=1626519675",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39375"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:15Z"
#             }
#         },
#         {
#             "@id": "mrgid/39413?t=1626519782",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39413"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:02Z"
#             }
#         },
#         {
#             "@id": "mrgid/39425?t=1626519694",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39425"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/39670?t=1626519614",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39670"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/39991?t=1626519628",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/39991"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:28Z"
#             }
#         },
#         {
#             "@id": "mrgid/40032?t=1626519827",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40032"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:47Z"
#             }
#         },
#         {
#             "@id": "mrgid/40154?t=1626519769",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40154"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:49Z"
#             }
#         },
#         {
#             "@id": "mrgid/40517?t=1626519791",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40517"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:11Z"
#             }
#         },
#         {
#             "@id": "mrgid/40693?t=1626519701",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40693"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:41Z"
#             }
#         },
#         {
#             "@id": "mrgid/40729?t=1626519748",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40729"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:28Z"
#             }
#         },
#         {
#             "@id": "mrgid/40756?t=1626519839",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/40756"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:59Z"
#             }
#         },
#         {
#             "@id": "mrgid/41209?t=1626519756",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41209"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/41294?t=1626519639",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41294"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:39Z"
#             }
#         },
#         {
#             "@id": "mrgid/41317?t=1626519630",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41317"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:30Z"
#             }
#         },
#         {
#             "@id": "mrgid/41426?t=1626519795",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41426"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:15Z"
#             }
#         },
#         {
#             "@id": "mrgid/41427?t=1626519710",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41427"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:50Z"
#             }
#         },
#         {
#             "@id": "mrgid/41453?t=1626519844",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41453"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/41472?t=1626519680",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/41472"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:20Z"
#             }
#         },
#         {
#             "@id": "mrgid/42123?t=1626519679",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42123"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:19Z"
#             }
#         },
#         {
#             "@id": "mrgid/42360?t=1626519630",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42360"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:30Z"
#             }
#         },
#         {
#             "@id": "mrgid/42634?t=1626519643",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42634"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:43Z"
#             }
#         },
#         {
#             "@id": "mrgid/42664?t=1626519613",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42664"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:13Z"
#             }
#         },
#         {
#             "@id": "mrgid/42683?t=1626519842",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42683"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:02Z"
#             }
#         },
#         {
#             "@id": "mrgid/42808?t=1626519604",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42808"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/42883?t=1626519700",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42883"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/42935?t=1626519651",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/42935"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:51Z"
#             }
#         },
#         {
#             "@id": "mrgid/43078?t=1626519655",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43078"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:55Z"
#             }
#         },
#         {
#             "@id": "mrgid/430?t=1626519777",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/430"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:57Z"
#             }
#         },
#         {
#             "@id": "mrgid/43370?t=1626519633",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43370"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/43374?t=1626519686",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43374"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:26Z"
#             }
#         },
#         {
#             "@id": "mrgid/43556?t=1626519609",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43556"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:09Z"
#             }
#         },
#         {
#             "@id": "mrgid/43668?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43668"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/43894?t=1626519702",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/43894"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:42Z"
#             }
#         },
#         {
#             "@id": "mrgid/44111?t=1626519644",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44111"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:44Z"
#             }
#         },
#         {
#             "@id": "mrgid/44128?t=1626519798",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44128"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:18Z"
#             }
#         },
#         {
#             "@id": "mrgid/44341?t=1626519766",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44341"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:46Z"
#             }
#         },
#         {
#             "@id": "mrgid/44681?t=1626519775",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44681"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:55Z"
#             }
#         },
#         {
#             "@id": "mrgid/4475?t=1626519706",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/4475"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:46Z"
#             }
#         },
#         {
#             "@id": "mrgid/44788?t=1626519693",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44788"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/44862?t=1626519799",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44862"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:19Z"
#             }
#         },
#         {
#             "@id": "mrgid/44926?t=1626519678",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/44926"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:18Z"
#             }
#         },
#         {
#             "@id": "mrgid/45020?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45020"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/45178?t=1626519809",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45178"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:29Z"
#             }
#         },
#         {
#             "@id": "mrgid/45202?t=1626519831",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45202"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:51Z"
#             }
#         },
#         {
#             "@id": "mrgid/45598?t=1626519826",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45598"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:46Z"
#             }
#         },
#         {
#             "@id": "mrgid/45648?t=1626519627",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45648"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:27Z"
#             }
#         },
#         {
#             "@id": "mrgid/45678?t=1626519688",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45678"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:28Z"
#             }
#         },
#         {
#             "@id": "mrgid/45702?t=1626519731",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45702"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:11Z"
#             }
#         },
#         {
#             "@id": "mrgid/45748?t=1626519780",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45748"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:00Z"
#             }
#         },
#         {
#             "@id": "mrgid/45904?t=1626519654",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45904"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:54Z"
#             }
#         },
#         {
#             "@id": "mrgid/45943?t=1626519757",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45943"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:37Z"
#             }
#         },
#         {
#             "@id": "mrgid/45?t=1626519692",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/45"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:32Z"
#             }
#         },
#         {
#             "@id": "mrgid/46383?t=1626519694",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/46383"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/46647?t=1626519814",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/46647"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/4689?t=1626519807",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/4689"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:27Z"
#             }
#         },
#         {
#             "@id": "mrgid/46952?t=1626519659",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/46952"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:59Z"
#             }
#         },
#         {
#             "@id": "mrgid/47198?t=1626519813",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/47198"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/47342?t=1626519836",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/47342"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:56Z"
#             }
#         },
#         {
#             "@id": "mrgid/47382?t=1626519834",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/47382"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:54Z"
#             }
#         },
#         {
#             "@id": "mrgid/4785?t=1626519759",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/4785"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:39Z"
#             }
#         },
#         {
#             "@id": "mrgid/47903?t=1626519707",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/47903"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:47Z"
#             }
#         },
#         {
#             "@id": "mrgid/47971?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/47971"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/48059?t=1626519805",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/48059"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
# ...
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:21Z"
#             }
#         },
#         {
#             "@id": "mrgid/53599?t=1626519639",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/53599"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:39Z"
#             }
#         },
#         {
#             "@id": "mrgid/53888?t=1626519615",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/53888"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:15Z"
#             }
#         },
#         {
#             "@id": "mrgid/54020?t=1626519693",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54020"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/541?t=1626519754",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/541"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:34Z"
#             }
#         },
#         {
#             "@id": "mrgid/54319?t=1626519836",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54319"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:56Z"
#             }
#         },
#         {
#             "@id": "mrgid/54368?t=1626519640",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54368"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/5445?t=1626519735",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/5445"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:15Z"
#             }
#         },
#         {
#             "@id": "mrgid/54485?t=1626519671",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54485"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:11Z"
#             }
#         },
#         {
#             "@id": "mrgid/54534?t=1626519779",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54534"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:59Z"
#             }
#         },
#         {
#             "@id": "mrgid/54809?t=1626519737",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/54809"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:17Z"
#             }
#         },
#         {
#             "@id": "mrgid/5481?t=1626519844",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/5481"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/55007?t=1626519784",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55007"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/55097?t=1626519651",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55097"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:51Z"
#             }
#         },
#         {
#             "@id": "mrgid/55278?t=1626519811",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55278"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:31Z"
#             }
#         },
#         {
#             "@id": "mrgid/55311?t=1626519841",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55311"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:01Z"
#             }
#         },
#         {
#             "@id": "mrgid/55315?t=1626519703",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55315"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:43Z"
#             }
#         },
#         {
#             "@id": "mrgid/55460?t=1626519633",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55460"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:33Z"
#             }
#         },
#         {
#             "@id": "mrgid/55499?t=1626519636",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55499"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:36Z"
#             }
#         },
#         {
#             "@id": "mrgid/55786?t=1626519652",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/55786"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:52Z"
#             }
#         },
#         {
#             "@id": "mrgid/56406?t=1626519647",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/56406"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:47Z"
#             }
#         },
#         {
#             "@id": "mrgid/56595?t=1626519844",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/56595"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:04:04Z"
#             }
#         },
#         {
#             "@id": "mrgid/56718?t=1626519648",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/56718"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:48Z"
#             }
#         },
#         {
#             "@id": "mrgid/56830?t=1626519626",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/56830"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:26Z"
#             }
#         },
#         {
#             "@id": "mrgid/56844?t=1626519700",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/56844"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/57203?t=1626519742",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/57203"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:22Z"
#             }
#         },
#         {
#             "@id": "mrgid/57632?t=1626519710",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/57632"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:50Z"
#             }
#         },
#         {
#             "@id": "mrgid/57985?t=1626519624",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/57985"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:24Z"
#             }
#         },
#         {
#             "@id": "mrgid/58159?t=1626519611",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/58159"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:11Z"
#             }
#         },
#         {
#             "@id": "mrgid/58224?t=1626519667",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/58224"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:07Z"
#             }
#         },
#         {
#             "@id": "mrgid/58263?t=1626519794",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/58263"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:14Z"
#             }
#         },
#         {
#             "@id": "mrgid/59268?t=1626519829",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/59268"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:49Z"
#             }
#         },
#         {
#             "@id": "mrgid/59353?t=1626519711",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/59353"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:51Z"
#             }
#         },
#         {
#             "@id": "mrgid/59455?t=1626519740",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/59455"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:20Z"
#             }
#         },
#         {
#             "@id": "mrgid/59746?t=1626519607",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/59746"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:07Z"
#             }
#         },
#         {
#             "@id": "mrgid/60959?t=1626519738",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/60959"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:18Z"
#             }
#         },
#         {
#             "@id": "mrgid/61920?t=1626519790",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/61920"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:10Z"
#             }
#         },
#         {
#             "@id": "mrgid/62615?t=1626519697",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/62615"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:37Z"
#             }
#         },
#         {
#             "@id": "mrgid/63280?t=1626519635",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/63280"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:35Z"
#             }
#         },
#         {
#             "@id": "mrgid/782?t=1626519700",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/782"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:40Z"
#             }
#         },
#         {
#             "@id": "mrgid/785?t=1626519749",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/785"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:29Z"
#             }
#         },
#         {
#             "@id": "mrgid/849?t=1626519808",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/849"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:28Z"
#             }
#         },
#         {
#             "@id": "mrgid/8674?t=1626519601",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/8674"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:01Z"
#             }
#         },
#         {
#             "@id": "mrgid/8721?t=1626519723",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/8721"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:03Z"
#             }
#         },
#         {
#             "@id": "mrgid/8740?t=1626519625",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/8740"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:00:25Z"
#             }
#         },
#         {
#             "@id": "mrgid/8839?t=1626519695",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/8839"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:35Z"
#             }
#         },
#         {
#             "@id": "mrgid/8926?t=1626519758",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/8926"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:38Z"
#             }
#         },
#         {
#             "@id": "mrgid/94?t=1626519764",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/94"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:02:44Z"
#             }
#         },
#         {
#             "@id": "mrgid/95?t=1626519705",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/95"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:01:45Z"
#             }
#         },
#         {
#             "@id": "mrgid/983?t=1626519816",
#             "dcterms:isVersionOf": {
#                 "@id": "mrgid/983"
#             },
#             "dcterms:modified": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
#                 "@value": "2021-07-17T11:03:36Z"
#             }
#         }
#     ]
# }
