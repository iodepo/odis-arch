# %% [markdown]
# # Sitemap Check Simple

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
# import dask, boto3
# import dask.dataframe as dd
import numpy as np
import json
import geopandas
import matplotlib.pyplot as plt
import shapely
# import kglab as kg
# Out:
# /home/fils/.local/lib/python3.10/site-packages/rdflib_jsonld/__init__.py:9: DeprecationWarning: The rdflib-jsonld package has been integrated into rdflib as of rdflib==6.0.1.  Please remove rdflib-jsonld from your project's dependencies.
#   warnings.warn(

# %%
sparqlep = "http://graph.oceaninfohub.org/blazegraph/namespace/oih/sparql"

# %%
#@title
def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# Count by org query

# %%
rq_prov = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

       SELECT   ( COUNT(?hm) as ?count) ?wat  ?orgname ?domain
        WHERE
        {
           # ?hm prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        GROUP BY ?wat ?orgname ?domain
        ORDER BY DESC(?count)
        """

# %%
dfp = get_sparql_dataframe(sparqlep, rq_prov)
dfp['count'] = dfp["count"].astype(int) # convert count c to int
dfp.set_index('orgname', inplace=True)
dfp
# Out:
#                                                     count  \
# orgname
# EurOcean Vessels                                     8373
# EurOcean Organizations                               8373
# EurOcean Projects                                    8373
# European Directory of Marine Organisations (EDM...   4726
# EDMO SeaDataNet                                      4693
# Ocean Biodiversity Information System                4580
# Ocean Biodiversity Information System                4424
# European Directory of Marine Environmental Rese...   3429
# EDMERP SeaDataNet                                    3422
# European Marine Observation and Data Network ca...   1180
# CIOOS                                                 498
# Marine Training EU                                    451
# Marine Training EU                                    444
# IOC Africa Data Portal                                253
# AquaDocs                                                1
# INVEMAR documents                                       1
# INVEMAR Experts                                         1
# INVEMAR institution                                     1
# INVEMAR training                                        1
# INVEMAR vessel                                          1
# Ocean Best Practices                                    1
# CHM LAC - Institutions                                  1
# CHM LAC - Experts                                       1
# MASPAWIO - Marine Spatial Atlas for the Western...      1
# CHM LAC - Documents                                     1
# CHM LAC - Training                                      1
# Benguela Current Convention (BCC) GeoData Portal        1
# Caribbean Marine Atlas catalogue                        1
#
#                                                                                                   wat  \
# orgname
# EurOcean Vessels                                                 https://catalogue.odis.org/view/2993
# EurOcean Organizations                                           https://catalogue.odis.org/view/2993
# EurOcean Projects                                                https://catalogue.odis.org/view/2993
# European Directory of Marine Organisations (EDM...      https://oceaninfohub.org/.well-known/org/edmo
# EDMO SeaDataNet                                     https://www.re3data.org/repository/seadatanet/...
# Ocean Biodiversity Information System                             https://catalogue.odis.org/view/343
# Ocean Biodiversity Information System                         https://www.re3data.org/repository/obis
# European Directory of Marine Environmental Rese...    https://oceaninfohub.org/.well-known/org/edmerp
# EDMERP SeaDataNet                                   https://www.re3data.org/repository/seadatanet/...
# European Marine Observation and Data Network ca...                https://catalogue.odis.org/view/364
# CIOOS                                                  https://oceaninfohub.org/.well-known/org/cioos
# Marine Training EU                                               https://catalogue.odis.org/view/1972
# Marine Training EU                                  https://www.re3data.org/repository/marinetraining
# IOC Africa Data Portal                              https://oceaninfohub.org/.well-known/org/afric...
# AquaDocs                                                             http://hdl.handle.net/1834/41372
# INVEMAR documents                                                http://example.org/invemar/documents
# INVEMAR Experts                                                    http://example.org/invemar/experts
# INVEMAR institution                                            http://example.org/invemar/institution
# INVEMAR training                                                  http://example.org/invemar/training
# INVEMAR vessel                                                      http://example.org/invemar/vessel
# Ocean Best Practices                                                  http://example.org/invemar/obps
# CHM LAC - Institutions                              https://oceaninfohub.org/.well-known/org/invem...
# CHM LAC - Experts                                   https://oceaninfohub.org/.well-known/org/invem...
# MASPAWIO - Marine Spatial Atlas for the Western...                https://catalogue.odis.org/view/351
# CHM LAC - Documents                                 https://oceaninfohub.org/.well-known/org/invem...
# CHM LAC - Training                                  https://oceaninfohub.org/.well-known/org/invem...
# Benguela Current Convention (BCC) GeoData Portal    https://oceaninfohub.org/.well-known/org/bengu...
# Caribbean Marine Atlas catalogue                                  https://catalogue.odis.org/view/616
#
#                                                                                                domain
# orgname
# EurOcean Vessels                                                        https://infohub.eurocean.net/
# EurOcean Organizations                                                  https://infohub.eurocean.net/
# EurOcean Projects                                                       https://infohub.eurocean.net/
# European Directory of Marine Organisations (EDM...                        https://edmo.seadatanet.org
# EDMO SeaDataNet                                                           https://edmo.seadatanet.org
# Ocean Biodiversity Information System                                                https://obis.org
# Ocean Biodiversity Information System                                                https://obis.org
# European Directory of Marine Environmental Rese...                      https://edmerp.seadatanet.org
# EDMERP SeaDataNet                                                       https://edmerp.seadatanet.org
# European Marine Observation and Data Network ca...                      https://emodnet.ec.europa.eu/
# CIOOS                                                                               https://cioos.ca/
# Marine Training EU                                                         https://marinetraining.eu/
# Marine Training EU                                                         https://marinetraining.eu/
# IOC Africa Data Portal                                                         https://ioc-africa.org
# AquaDocs                                                                         https://aquadocs.org
# INVEMAR documents                                   http://portete.invemar.org.co/chm/api/oih/docu...
# INVEMAR Experts                                      http://portete.invemar.org.co/chm/api/oih/expert
# INVEMAR institution                                 http://portete.invemar.org.co/chm/api/oih/inst...
# INVEMAR training                                    http://portete.invemar.org.co/chm/api/oih/trai...
# INVEMAR vessel                                       http://portete.invemar.org.co/chm/api/oih/vessel
# Ocean Best Practices                                               https://oih.oceanbestpractices.org
# CHM LAC - Institutions                                                  http://portete.invemar.org.co
# CHM LAC - Experts                                                       http://portete.invemar.org.co
# MASPAWIO - Marine Spatial Atlas for the Western...                              https://cordioea.net/
# CHM LAC - Documents                                                     http://portete.invemar.org.co
# CHM LAC - Training                                                      http://portete.invemar.org.co
# Benguela Current Convention (BCC) GeoData Portal                          https://www.benguelacc.org/
# Caribbean Marine Atlas catalogue                                https://www.caribbeanmarineatlas.net/

# %%
import pandas as pd
import requests

url = "https://raw.githubusercontent.com/iodepo/odis-arch/schema-dev-df/workflows/actions/sitemapcheck/test.csv"
r = requests.get(url)
open('temp.csv', 'wb').write(r.content)
df = pd.read_csv('temp.csv')

# %%
df.rename(columns={'propername':'orgname'}, inplace=True)

# %%
df
# Out:
#                     name                                            orgname  \
# 0              africaioc                             IOC Africa Data Portal
# 1               aquadocs                                           AquaDocs
# 2             benguelacc   Benguela Current Convention (BCC) GeoData Portal
# 3   caribbeanmarineatlas                   Caribbean Marine Atlas catalogue
# 4                  cioos                                              CIOOS
# 5                 edmerp  European Directory of Marine Environmental Res...
# 6                   edmo  European Directory of Marine Organisations (ED...
# 7         euroceanevents                                    EurOcean Events
# 8        euroceanexperts                                   EurOcean Experts
# 9   euroceaninstitutions                              EurOcean Institutions
# 10          euroceanorgs                             EurOcean Organizations
# 11      euroceanprojects                                  EurOcean Projects
# 12      euroceantraining                                  EurOcean Training
# 13       euroceanvessels                                   EurOcean Vessels
# 14               emodnet  European Marine Observation and Data Network c...
# 15               inanodc             Indonesia National Oceanic Data Center
# 16      invemardocuments                                CHM LAC - Documents
# 17        invemarexperts                                  CHM LAC - Experts
# 18   invemarinstitutions                             CHM LAC - Institutions
# 19       invemartraining                                 CHM LAC - Training
# 20        invemarvessels                                  CHM LAC - Vessels
# 21        marinetraining                                 Marine Training EU
# 22              maspawio  MASPAWIO - Marine Spatial Atlas for the Wester...
# 23                  obis              Ocean Biodiversity Information System
# 24                  obps                        Ocean Best Practices System
# 25          oceanexperts     OceanExpert UNESCO/IOC Project Office for IODE
# 26            oceanscape                                 Oceanscape Project
# 27                   pdh                                   Pacific Data Hub
# 28                  pogo    Partnership for Observation of the Global Ocean
#
#     code                                        description  \
# 0      0  440 : africaioc VALID https://ioc-africa.org/s...
# 1      0  aquadocs \t https://oih.aquadocs.org/aquadocs....
# 2      0  benguelacc \t https://raw.githubusercontent.co...
# 3      0  caribbeanmarineatlas \t https://raw.githubuser...
# 4      0  507 : cioos VALID https://catalogue.cioos.ca/s...
# 5      0  3430 : edmerp VALID https://edmerp.seadatanet....
# 6      0  4726 : edmo VALID https://edmo.seadatanet.org/...
# 7      1  ERROR euroceanevents : https://www.oceanexpert...
# 8      1  ERROR euroceanexperts : https://www.oceanexper...
# 9      1  ERROR euroceaninstitutions : https://www.ocean...
# 10     0  7651 : euroceanorgs VALID https://infohub.euro...
# 11     0  635 : euroceanprojects VALID https://infohub.e...
# 12     1  ERROR euroceantraining : https://www.oceanexpe...
# 13     0  87 : euroceanvessels VALID https://infohub.eur...
# 14     0  2174 : emodnet VALID https://emodnet.ec.europa...
# 15     0  33 : inanodc VALID https://geonode.nodc.id/sit...
# 16     0  invemardocuments \t http://portete.invemar.org...
# 17     0  invemarexperts \t http://portete.invemar.org.c...
# 18     0  invemarinstitutions \t http://portete.invemar....
# 19     0  invemartraining \t http://portete.invemar.org....
# 20     0  invemarvessels \t http://portete.invemar.org.c...
# 21     0  658 : marinetraining VALID https://www.marinet...
# 22     0  maspawio \t https://raw.githubusercontent.com/...
# 23     0  4636 : obis VALID https://obis.org/sitemap_dat...
# 24     0  obps \t https://oih.oceanbestpractices.org/obp...
# 25     1  ERROR oceanexperts : https://oceanexpert.org/a...
# 26     0  115 : oceanscape VALID https://oceanscape.org/...
# 27     0  53 : pdh VALID https://pacificdata.org/organiz...
# 28     0  81 : pogo VALID https://pogo-ocean.org/pogo-me...
#
#                                                   url       type
# 0                  https://ioc-africa.org/sitemap.xml    sitemap
# 1              https://oih.aquadocs.org/aquadocs.json  sitegraph
# 2   https://raw.githubusercontent.com/iodepo/odis-...  sitegraph
# 3   https://raw.githubusercontent.com/iodepo/odis-...  sitegraph
# 4      https://catalogue.cioos.ca/sitemap/sitemap.xml    sitemap
# 5           https://edmerp.seadatanet.org/sitemap.xml    sitemap
# 6             https://edmo.seadatanet.org/sitemap.xml    sitemap
# 7   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap
# 8   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap
# 9   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap
# 10  https://infohub.eurocean.net/sitemap/organizat...    sitemap
# 11      https://infohub.eurocean.net/sitemap/projects    sitemap
# 12  https://www.oceanexpert.org/assets/sitemaps/si...    sitemap
# 13       https://infohub.eurocean.net/sitemap/vessels    sitemap
# 14  https://emodnet.ec.europa.eu/geonetwork/srv/en...    sitemap
# 15                https://geonode.nodc.id/sitemap.xml    sitemap
# 16  http://portete.invemar.org.co/chm/api/oih/docu...  sitegraph
# 17  http://portete.invemar.org.co/chm/api/oih/expe...  sitegraph
# 18  http://portete.invemar.org.co/chm/api/oih/inst...  sitegraph
# 19  http://portete.invemar.org.co/chm/api/oih/trai...  sitegraph
# 20  http://portete.invemar.org.co/chm/api/oih/vess...  sitegraph
# 21          https://www.marinetraining.eu/sitemap.xml    sitemap
# 22  https://raw.githubusercontent.com/iodepo/odis-...  sitegraph
# 23              https://obis.org/sitemap_datasets.xml    sitemap
# 24       https://oih.oceanbestpractices.org/obps.json  sitegraph
# 25  https://oceanexpert.org/assets/sitemaps/sitema...    sitemap
# 26    https://oceanscape.org/organisation-sitemap.xml    sitemap
# 27   https://pacificdata.org/organization/sitemap.xml    sitemap
# 28     https://pogo-ocean.org/pogo-member-sitemap.xml    sitemap

# %%
dfm = pd.merge(df, dfp, on='orgname', how='outer', left_index=False)
dfm = dfm.reset_index(drop=True)

# %%
# move columns
# sort on code with 1 at the top

# %%
dfmreport = dfm[['code', 'count', 'name', 'orgname', 'type']]
dfmreport.sort_values('code', ascending=False).reset_index(drop=True)
# dfmreport = dfmreport.reset_index()

# could change all the values to -1 and alter the highlighter

def highlight_greaterthan(s, threshold, column):
    is_max = pd.Series(data=False, index=s.index)
    is_max[column] = s.loc[column] >= threshold
    return ['background-color: pink' if is_max.any() else '' for v in is_max]

dfmreport.style.apply(highlight_greaterthan, threshold=1.0, column=['code'], axis=1)
# Out:
# <style type="text/css">
# #T_edea8_row7_col0, #T_edea8_row7_col1, #T_edea8_row7_col2, #T_edea8_row7_col3, #T_edea8_row7_col4, #T_edea8_row8_col0, #T_edea8_row8_col1, #T_edea8_row8_col2, #T_edea8_row8_col3, #T_edea8_row8_col4, #T_edea8_row9_col0, #T_edea8_row9_col1, #T_edea8_row9_col2, #T_edea8_row9_col3, #T_edea8_row9_col4, #T_edea8_row12_col0, #T_edea8_row12_col1, #T_edea8_row12_col2, #T_edea8_row12_col3, #T_edea8_row12_col4, #T_edea8_row27_col0, #T_edea8_row27_col1, #T_edea8_row27_col2, #T_edea8_row27_col3, #T_edea8_row27_col4 {
#   background-color: pink;
# }
# </style>
# <table id="T_edea8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edea8_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_edea8_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_edea8_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_edea8_level0_col3" class="col_heading level0 col3" >orgname</th>
#       <th id="T_edea8_level0_col4" class="col_heading level0 col4" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edea8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edea8_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_edea8_row0_col1" class="data row0 col1" >253.000000</td>
#       <td id="T_edea8_row0_col2" class="data row0 col2" >africaioc</td>
#       <td id="T_edea8_row0_col3" class="data row0 col3" >IOC Africa Data Portal</td>
#       <td id="T_edea8_row0_col4" class="data row0 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edea8_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_edea8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_edea8_row1_col2" class="data row1 col2" >aquadocs</td>
#       <td id="T_edea8_row1_col3" class="data row1 col3" >AquaDocs</td>
#       <td id="T_edea8_row1_col4" class="data row1 col4" >sitegraph</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edea8_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_edea8_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_edea8_row2_col2" class="data row2 col2" >benguelacc</td>
#       <td id="T_edea8_row2_col3" class="data row2 col3" >Benguela Current Convention (BCC) GeoData Portal</td>
#       <td id="T_edea8_row2_col4" class="data row2 col4" >sitegraph</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edea8_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_edea8_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_edea8_row3_col2" class="data row3 col2" >caribbeanmarineatlas</td>
#       <td id="T_edea8_row3_col3" class="data row3 col3" >Caribbean Marine Atlas catalogue</td>
#       <td id="T_edea8_row3_col4" class="data row3 col4" >sitegraph</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edea8_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_edea8_row4_col1" class="data row4 col1" >498.000000</td>
#       <td id="T_edea8_row4_col2" class="data row4 col2" >cioos</td>
#       <td id="T_edea8_row4_col3" class="data row4 col3" >CIOOS</td>
#       <td id="T_edea8_row4_col4" class="data row4 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edea8_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_edea8_row5_col1" class="data row5 col1" >3429.000000</td>
#       <td id="T_edea8_row5_col2" class="data row5 col2" >edmerp</td>
#       <td id="T_edea8_row5_col3" class="data row5 col3" >European Directory of Marine Environmental Research Projects (EDMERP) SeaDataNet</td>
#       <td id="T_edea8_row5_col4" class="data row5 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edea8_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_edea8_row6_col1" class="data row6 col1" >4726.000000</td>
#       <td id="T_edea8_row6_col2" class="data row6 col2" >edmo</td>
#       <td id="T_edea8_row6_col3" class="data row6 col3" >European Directory of Marine Organisations (EDMO) SeaDataNet</td>
#       <td id="T_edea8_row6_col4" class="data row6 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edea8_row7_col0" class="data row7 col0" >1.000000</td>
#       <td id="T_edea8_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_edea8_row7_col2" class="data row7 col2" >euroceanevents</td>
#       <td id="T_edea8_row7_col3" class="data row7 col3" >EurOcean Events</td>
#       <td id="T_edea8_row7_col4" class="data row7 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_edea8_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_edea8_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_edea8_row8_col2" class="data row8 col2" >euroceanexperts</td>
#       <td id="T_edea8_row8_col3" class="data row8 col3" >EurOcean Experts</td>
#       <td id="T_edea8_row8_col4" class="data row8 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_edea8_row9_col0" class="data row9 col0" >1.000000</td>
#       <td id="T_edea8_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_edea8_row9_col2" class="data row9 col2" >euroceaninstitutions</td>
#       <td id="T_edea8_row9_col3" class="data row9 col3" >EurOcean Institutions</td>
#       <td id="T_edea8_row9_col4" class="data row9 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_edea8_row10_col0" class="data row10 col0" >0.000000</td>
#       <td id="T_edea8_row10_col1" class="data row10 col1" >8373.000000</td>
#       <td id="T_edea8_row10_col2" class="data row10 col2" >euroceanorgs</td>
#       <td id="T_edea8_row10_col3" class="data row10 col3" >EurOcean Organizations</td>
#       <td id="T_edea8_row10_col4" class="data row10 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_edea8_row11_col0" class="data row11 col0" >0.000000</td>
#       <td id="T_edea8_row11_col1" class="data row11 col1" >8373.000000</td>
#       <td id="T_edea8_row11_col2" class="data row11 col2" >euroceanprojects</td>
#       <td id="T_edea8_row11_col3" class="data row11 col3" >EurOcean Projects</td>
#       <td id="T_edea8_row11_col4" class="data row11 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_edea8_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_edea8_row12_col1" class="data row12 col1" >nan</td>
#       <td id="T_edea8_row12_col2" class="data row12 col2" >euroceantraining</td>
#       <td id="T_edea8_row12_col3" class="data row12 col3" >EurOcean Training</td>
#       <td id="T_edea8_row12_col4" class="data row12 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_edea8_row13_col0" class="data row13 col0" >0.000000</td>
#       <td id="T_edea8_row13_col1" class="data row13 col1" >8373.000000</td>
#       <td id="T_edea8_row13_col2" class="data row13 col2" >euroceanvessels</td>
#       <td id="T_edea8_row13_col3" class="data row13 col3" >EurOcean Vessels</td>
#       <td id="T_edea8_row13_col4" class="data row13 col4" >sitemap</td>
#     </tr>
#     <tr>
#       <th id="T_edea8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_edea8_row14_col0" class="data row14 col0" >0.000000</td>
#       <td id="T_edea8_row14_col1" class="data row14 col1" >1180.000000</td>
#       <td id="T_edea8_row14_c
