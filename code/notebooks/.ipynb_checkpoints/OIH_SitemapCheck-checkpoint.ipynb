# %% [markdown]
# # Sitemap Check Simple

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
# import dask, boto3
# import dask.dataframe as dd
import numpy as np
import json
import geopandas
import matplotlib.pyplot as plt
import shapely
# import kglab as kg
# Out:
# /home/fils/.local/lib/python3.10/site-packages/rdflib_jsonld/__init__.py:9: DeprecationWarning: The rdflib-jsonld package has been integrated into rdflib as of rdflib==6.0.1.  Please remove rdflib-jsonld from your project's dependencies.
#   warnings.warn(

# %%
sparqlep = "http://graph.oceaninfohub.org/blazegraph/namespace/oih/sparql"

# %%
#@title
def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %%
rq_prov = """prefix prov: <http://www.w3.org/ns/prov#>
        PREFIX con: <http://www.ontotext.com/connectors/lucene#>
        PREFIX luc: <http://www.ontotext.com/owlim/lucene#>
        PREFIX con-inst: <http://www.ontotext.com/connectors/lucene/instance#>
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
        PREFIX schema: <https://schema.org/>
        PREFIX schemaold: <http://schema.org/>
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

       SELECT   ( COUNT(?hm) as ?count) ?wat  ?orgname ?domain
        WHERE
        {
           # ?hm prov:wasAttributedTo ?wat .
           # ?wat rdf:name ?orgname .
           # ?wat rdfs:seeAlso ?domain
        }
        GROUP BY ?wat ?orgname ?domain
        ORDER BY DESC(?count)
        """

# %%
dfp = get_sparql_dataframe(sparqlep, rq_prov)
dfp['count'] = dfp["count"].astype(int) # convert count c to int
# dfp.set_index('orgname', inplace=True)

# %%
dfp
# Out:
#     count                                                wat  \
# 0    8373               https://catalogue.odis.org/view/2993
# 1    8373               https://catalogue.odis.org/view/2993
# 2    8373               https://catalogue.odis.org/view/2993
# 3    4726      https://oceaninfohub.org/.well-known/org/edmo
# 4    4693  https://www.re3data.org/repository/seadatanet/...
# 5    4580                https://catalogue.odis.org/view/343
# 6    4424            https://www.re3data.org/repository/obis
# 7    3429    https://oceaninfohub.org/.well-known/org/edmerp
# 8    3422  https://www.re3data.org/repository/seadatanet/...
# 9    1183                https://catalogue.odis.org/view/364
# 10    498     https://oceaninfohub.org/.well-known/org/cioos
# 11    451               https://catalogue.odis.org/view/1972
# 12    444  https://www.re3data.org/repository/marinetraining
# 13    253  https://oceaninfohub.org/.well-known/org/afric...
# 14     33               https://catalogue.odis.org/view/3246
# 15      1                   http://hdl.handle.net/1834/41372
# 16      1               http://example.org/invemar/documents
# 17      1                 http://example.org/invemar/experts
# 18      1             http://example.org/invemar/institution
# 19      1                http://example.org/invemar/training
# 20      1                  http://example.org/invemar/vessel
# 21      1                    http://example.org/invemar/obps
# 22      1  https://oceaninfohub.org/.well-known/org/invem...
# 23      1  https://oceaninfohub.org/.well-known/org/invem...
# 24      1                https://catalogue.odis.org/view/351
# 25      1  https://oceaninfohub.org/.well-known/org/invem...
# 26      1  https://oceaninfohub.org/.well-known/org/invem...
# 27      1  https://oceaninfohub.org/.well-known/org/invem...
# 28      1  https://oceaninfohub.org/.well-known/org/bengu...
# 29      1                https://catalogue.odis.org/view/616
#
#                                               orgname  \
# 0                                    EurOcean Vessels
# 1                                   EurOcean Projects
# 2                              EurOcean Organizations
# 3   European Directory of Marine Organisations (ED...
# 4                                     EDMO SeaDataNet
# 5               Ocean Biodiversity Information System
# 6               Ocean Biodiversity Information System
# 7   European Directory of Marine Environmental Res...
# 8                                   EDMERP SeaDataNet
# 9   European Marine Observation and Data Network c...
# 10                                              CIOOS
# 11                                 Marine Training EU
# 12                                 Marine Training EU
# 13                             IOC Africa Data Portal
# 14             Indonesia National Oceanic Data Center
# 15                                           AquaDocs
# 16                                  INVEMAR documents
# 17                                    INVEMAR Experts
# 18                                INVEMAR institution
# 19                                   INVEMAR training
# 20                                     INVEMAR vessel
# 21                               Ocean Best Practices
# 22                             CHM LAC - Institutions
# 23                                  CHM LAC - Experts
# 24  MASPAWIO - Marine Spatial Atlas for the Wester...
# 25                                  CHM LAC - Vessels
# 26                                CHM LAC - Documents
# 27                                 CHM LAC - Training
# 28   Benguela Current Convention (BCC) GeoData Portal
# 29                   Caribbean Marine Atlas catalogue
#
#                                                domain
# 0                       https://infohub.eurocean.net/
# 1                       https://infohub.eurocean.net/
# 2                       https://infohub.eurocean.net/
# 3                         https://edmo.seadatanet.org
# 4                         https://edmo.seadatanet.org
# 5                                    https://obis.org
# 6                                    https://obis.org
# 7                       https://edmerp.seadatanet.org
# 8                       https://edmerp.seadatanet.org
# 9                       https://emodnet.ec.europa.eu/
# 10                                  https://cioos.ca/
# 11                         https://marinetraining.eu/
# 12                         https://marinetraining.eu/
# 13                             https://ioc-africa.org
# 14                                    https://nodc.id
# 15                               https://aquadocs.org
# 16  http://portete.invemar.org.co/chm/api/oih/docu...
# 17   http://portete.invemar.org.co/chm/api/oih/expert
# 18  http://portete.invemar.org.co/chm/api/oih/inst...
# 19  http://portete.invemar.org.co/chm/api/oih/trai...
# 20   http://portete.invemar.org.co/chm/api/oih/vessel
# 21                 https://oih.oceanbestpractices.org
# 22                      http://portete.invemar.org.co
# 23                      http://portete.invemar.org.co
# 24                              https://cordioea.net/
# 25                      http://portete.invemar.org.co
# 26                      http://portete.invemar.org.co
# 27                      http://portete.invemar.org.co
# 28                        https://www.benguelacc.org/
# 29              https://www.caribbeanmarineatlas.net/

# %%
import pandas as pd
import requests

url = "https://raw.githubusercontent.com/iodepo/odis-arch/schema-dev-df/workflows/actions/sitemapcheck/test.csv"
r = requests.get(url)
open('temp.csv', 'wb').write(r.content)
df = pd.read_csv('temp.csv')

# %%
df.rename(columns={'propername':'orgname'}, inplace=True)

# %%
dfm = pd.merge(df, dfp, on='orgname', how='outer', left_index=False)
dfm = dfm.reset_index()

# %%
dfm.to_csv("sourcemerge.csv")

# %%
dfm
# Out:
#     index                  name  \
# 0       0             africaioc
# 1       1              aquadocs
# 2       2            benguelacc
# 3       3  caribbeanmarineatlas
# 4       4                 cioos
# 5       5                edmerp
# 6       6                  edmo
# 7       7        euroceanevents
# 8       8       euroceanexperts
# 9       9  euroceaninstitutions
# 10     10          euroceanorgs
# 11     11      euroceanprojects
# 12     12      euroceantraining
# 13     13       euroceanvessels
# 14     14               emodnet
# 15     15               inanodc
# 16     16      invemardocuments
# 17     17        invemarexperts
# 18     18   invemarinstitutions
# 19     19       invemartraining
# 20     20        invemarvessels
# 21     21        marinetraining
# 22     22        marinetraining
# 23     23              maspawio
# 24     24                  obis
# 25     25                  obis
# 26     26                  obps
# 27     27          oceanexperts
# 28     28            oceanscape
# 29     29                   pdh
# 30     30                  pogo
# 31     31                   NaN
# 32     32                   NaN
# 33     33                   NaN
# 34     34                   NaN
# 35     35                   NaN
# 36     36                   NaN
# 37     37                   NaN
# 38     38                   NaN
#
#                                               orgname  code  \
# 0                              IOC Africa Data Portal   0.0
# 1                                            AquaDocs   0.0
# 2    Benguela Current Convention (BCC) GeoData Portal   0.0
# 3                    Caribbean Marine Atlas catalogue   0.0
# 4                                               CIOOS   0.0
# 5   European Directory of Marine Environmental Res...   0.0
# 6   European Directory of Marine Organisations (ED...   0.0
# 7                                     EurOcean Events   1.0
# 8                                    EurOcean Experts   1.0
# 9                               EurOcean Institutions   1.0
# 10                             EurOcean Organizations   0.0
# 11                                  EurOcean Projects   0.0
# 12                                  EurOcean Training   1.0
# 13                                   EurOcean Vessels   0.0
# 14  European Marine Observation and Data Network c...   0.0
# 15             Indonesia National Oceanic Data Center   0.0
# 16                                CHM LAC - Documents   0.0
# 17                                  CHM LAC - Experts   0.0
# 18                             CHM LAC - Institutions   0.0
# 19                                 CHM LAC - Training   0.0
# 20                                  CHM LAC - Vessels   0.0
# 21                                 Marine Training EU   0.0
# 22                                 Marine Training EU   0.0
# 23  MASPAWIO - Marine Spatial Atlas for the Wester...   0.0
# 24              Ocean Biodiversity Information System   0.0
# 25              Ocean Biodiversity Information System   0.0
# 26                        Ocean Best Practices System   0.0
# 27     OceanExpert UNESCO/IOC Project Office for IODE   1.0
# 28                                 Oceanscape Project   0.0
# 29                                   Pacific Data Hub   0.0
# 30    Partnership for Observation of the Global Ocean   0.0
# 31                                    EDMO SeaDataNet   NaN
# 32                                  EDMERP SeaDataNet   NaN
# 33                                  INVEMAR documents   NaN
# 34                                    INVEMAR Experts   NaN
# 35                                INVEMAR institution   NaN
# 36                                   INVEMAR training   NaN
# 37                                     INVEMAR vessel   NaN
# 38                               Ocean Best Practices   NaN
#
#                                           description  \
# 0   440 : africaioc VALID https://ioc-africa.org/s...
# 1   aquadocs \t https://oih.aquadocs.org/aquadocs....
# 2   benguelacc \t https://raw.githubusercontent.co...
# 3   caribbeanmarineatlas \t https://raw.githubuser...
# 4   507 : cioos VALID https://catalogue.cioos.ca/s...
# 5   3430 : edmerp VALID https://edmerp.seadatanet....
# 6   4726 : edmo VALID https://edmo.seadatanet.org/...
# 7   ERROR euroceanevents : https://www.oceanexpert...
# 8   ERROR euroceanexperts : https://www.oceanexper...
# 9   ERROR euroceaninstitutions : https://www.ocean...
# 10  7651 : euroceanorgs VALID https://infohub.euro...
# 11  635 : euroceanprojects VALID https://infohub.e...
# 12  ERROR euroceantraining : https://www.oceanexpe...
# 13  87 : euroceanvessels VALID https://infohub.eur...
# 14  2174 : emodnet VALID https://emodnet.ec.europa...
# 15  33 : inanodc VALID https://geonode.nodc.id/sit...
# 16  invemardocuments \t http://portete.invemar.org...
# 17  invemarexperts \t http://portete.invemar.org.c...
# 18  invemarinstitutions \t http://portete.invemar....
# 19  invemartraining \t http://portete.invemar.org....
# 20  invemarvessels \t http://portete.invemar.org.c...
# 21  658 : marinetraining VALID https://www.marinet...
# 22  658 : marinetraining VALID https://www.marinet...
# 23  maspawio \t https://raw.githubusercontent.com/...
# 24  4636 : obis VALID https://obis.org/sitemap_dat...
# 25  4636 : obis VALID https://obis.org/sitemap_dat...
# 26  obps \t https://oih.oceanbestpractices.org/obp...
# 27  ERROR oceanexperts : https://oceanexpert.org/a...
# 28  115 : oceanscape VALID https://oceanscape.org/...
# 29  53 : pdh VALID https://pacificdata.org/organiz...
# 30  81 : pogo VALID https://pogo-ocean.org/pogo-me...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                                   url       type   count  \
# 0                  https://ioc-africa.org/sitemap.xml    sitemap   253.0
# 1              https://oih.aquadocs.org/aquadocs.json  sitegraph     1.0
# 2   https://raw.githubusercontent.com/iodepo/odis-...  sitegraph     1.0
# 3   https://raw.githubusercontent.com/iodepo/odis-...  sitegraph     1.0
# 4      https://catalogue.cioos.ca/sitemap/sitemap.xml    sitemap   498.0
# 5           https://edmerp.seadatanet.org/sitemap.xml    sitemap  3429.0
# 6             https://edmo.seadatanet.org/sitemap.xml    sitemap  4726.0
# 7   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap     NaN
# 8   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap     NaN
# 9   https://www.oceanexpert.org/assets/sitemaps/si...    sitemap     NaN
# 10  https://infohub.eurocean.net/sitemap/organizat...    sitemap  8373.0
# 11      https://infohub.eurocean.net/sitemap/projects    sitemap  8373.0
# 12  https://www.oceanexpert.org/assets/sitemaps/si...    sitemap     NaN
# 13       https://infohub.eurocean.net/sitemap/vessels    sitemap  8373.0
# 14  https://emodnet.ec.europa.eu/geonetwork/srv/en...    sitemap  1183.0
# 15                https://geonode.nodc.id/sitemap.xml    sitemap    33.0
# 16  http://portete.invemar.org.co/chm/api/oih/docu...  sitegraph     1.0
# 17  http://portete.invemar.org.co/chm/api/oih/expe...  sitegraph     1.0
# 18  http://portete.invemar.org.co/chm/api/oih/inst...  sitegraph     1.0
# 19  http://portete.invemar.org.co/chm/api/oih/trai...  sitegraph     1.0
# 20  http://portete.invemar.org.co/chm/api/oih/vess...  sitegraph     1.0
# 21          https://www.marinetraining.eu/sitemap.xml    sitemap   451.0
# 22          https://www.marinetraining.eu/sitemap.xml    sitemap   444.0
# 23  https://raw.githubusercontent.com/iodepo/odis-...  sitegraph     1.0
# 24              https://obis.org/sitemap_datasets.xml    sitemap  4580.0
# 25              https://obis.org/sitemap_datasets.xml    sitemap  4424.0
# 26       https://oih.oceanbestpractices.org/obps.json  sitegraph     NaN
# 27  https://oceanexpert.org/assets/sitemaps/sitema...    sitemap     NaN
# 28    https://oceanscape.org/organisation-sitemap.xml    sitemap     NaN
# 29   https://pacificdata.org/organization/sitemap.xml    sitemap     NaN
# 30     https://pogo-ocean.org/pogo-member-sitemap.xml    sitemap     NaN
# 31                                                NaN        NaN  4693.0
# 32                                                NaN        NaN  3422.0
# 33                                                NaN        NaN     1.0
# 34                                                NaN        NaN     1.0
# 35                                                NaN        NaN     1.0
# 36                                                NaN        NaN     1.0
# 37                                                NaN        NaN     1.0
# 38                                                NaN        NaN     1.0
#
#                                                   wat  \
# 0   https://oceaninfohub.org/.well-known/org/afric...
# 1                    http://hdl.handle.net/1834/41372
# 2   https://oceaninfohub.org/.well-known/org/bengu...
# 3                 https://catalogue.odis.org/view/616
# 4      https://oceaninfohub.org/.well-known/org/cioos
# 5     https://oceaninfohub.org/.well-known/org/edmerp
# 6       https://oceaninfohub.org/.well-known/org/edmo
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10               https://catalogue.odis.org/view/2993
# 11               https://catalogue.odis.org/view/2993
# 12                                                NaN
# 13               https://catalogue.odis.org/view/2993
# 14                https://catalogue.odis.org/view/364
# 15               https://catalogue.odis.org/view/3246
# 16  https://oceaninfohub.org/.well-known/org/invem...
# 17  https://oceaninfohub.org/.well-known/org/invem...
# 18  https://oceaninfohub.org/.well-known/org/invem...
# 19  https://oceaninfohub.org/.well-known/org/invem...
# 20  https://oceaninfohub.org/.well-known/org/invem...
# 21               https://catalogue.odis.org/view/1972
# 22  https://www.re3data.org/repository/marinetraining
# 23                https://catalogue.odis.org/view/351
# 24                https://catalogue.odis.org/view/343
# 25            https://www.re3data.org/repository/obis
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  https://www.re3data.org/repository/seadatanet/...
# 32  https://www.re3data.org/repository/seadatanet/...
# 33               http://example.org/invemar/documents
# 34                 http://example.org/invemar/experts
# 35             http://example.org/invemar/institution
# 36                http://example.org/invemar/training
# 37                  http://example.org/invemar/vessel
# 38                    http://example.org/invemar/obps
#
#                                                domain
# 0                              https://ioc-africa.org
# 1                                https://aquadocs.org
# 2                         https://www.benguelacc.org/
# 3               https://www.caribbeanmarineatlas.net/
# 4                                   https://cioos.ca/
# 5                       https://edmerp.seadatanet.org
# 6                         https://edmo.seadatanet.org
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                      https://infohub.eurocean.net/
# 11                      https://infohub.eurocean.net/
# 12                                                NaN
# 13                      https://infohub.eurocean.net/
# 14                      https://emodnet.ec.europa.eu/
# 15                                    https://nodc.id
# 16                      http://portete.invemar.org.co
# 17                      http://portete.invemar.org.co
# 18                      http://portete.invemar.org.co
# 19                      http://portete.invemar.org.co
# 20                      http://portete.invemar.org.co
# 21                         https://marinetraining.eu/
# 22                         https://marinetraining.eu/
# 23                              https://cordioea.net/
# 24                                   https://obis.org
# 25                                   https://obis.org
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                        https://edmo.seadatanet.org
# 32                      https://edmerp.seadatanet.org
# 33  http://portete.invemar.org.co/chm/api/oih/docu...
# 34   http://portete.invemar.org.co/chm/api/oih/expert
# 35  http://portete.invemar.org.co/chm/api/oih/inst...
# 36  http://portete.invemar.org.co/chm/api/oih/trai...
# 37   http://portete.invemar.org.co/chm/api/oih/vessel
# 38                 https://oih.oceanbestpractices.org

# %% [markdown]
# # Panel testing

# %%
import pandas as pd; import numpy as np; import matplotlib.pyplot as plt

csv_file = 'https://raw.githubusercontent.com/holoviz/panel/main/examples/assets/occupancy.csv'
data = pd.read_csv(csv_file, parse_dates=['date'], index_col='date')

data.tail()
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy
# date
# 2015-02-10 09:29:00          1
# 2015-02-10 09:29:59          1
# 2015-02-10 09:30:59          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1

# %%
import matplotlib as mpl
mpl.use('agg')

from matplotlib.figure import Figure

def mpl_plot(avg, highlight):
    fig = Figure()
    ax = fig.add_subplot()
    avg.plot(ax=ax)
    if len(highlight): highlight.plot(style='o', ax=ax)
    return fig

def find_outliers(variable='Temperature', window=30, sigma=10, view_fn=mpl_plot):
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = (np.abs(residual) > std * sigma)
    return view_fn(avg, avg[outliers])

# %%
find_outliers(variable='Temperature', window=20, sigma=10)

# %%
import panel as pn
pn.extension()

window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

interactive = pn.bind(find_outliers, window=window, sigma=sigma)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
first_app = pn.Column(window, sigma, interactive)

first_app
# Out:
# Column
#     [0] IntSlider(end=60, name='window', start=1, value=30)
#     [1] IntSlider(end=20, name='sigma', value=10)
#     [2] ParamFunction(function, _pane=Matplotlib)
