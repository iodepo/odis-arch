# %% [markdown]
# # Named Entity Recognition for GeoPolitical Entities
#
# ## About
#
# This notebook is a simple test.  It performs the following:
#
# * Loads data from an S3 (Minio) source populated by [Gleaner](https://gleaner.io) into a Pandas data frame mediated by Dask
# * Loads SWEET labels into an additional Pandas data frame
# * Leverages SpaCy to extract entities from the data graph descriptions.
# * Compare the extracted entities (from descriptions) and the keywords from the data graph to the SWEET labels to looks for matches.
#
# This pattern could be used with other elements of the data graph or extracted entities and other vocabularies for linking.
#
# Additionally it provides an exmaple of comparing generated knowledge graphs from various sources with each other as well to resolve relations.
#
# ## Domain Entities
#
# What we really need is a domain entity linker like described at:
# https://github.com/allenai/scispacy#entitylinker in SciSpaCY.  However, we are not going to use SciSpaCY obviously, as it's more for biomedical.
#
# For now we will stick to SpaCY in this example.  Later it would be good train an entity extractor for the geoscience for SpaCY or other NLP packages.
#
# ## Checking WikiData
#
# We could do something like with SWEET but for WikiDATA.  However, a search at https://query.wikidata.org/ like:
#
# ```
# SELECT *
# WHERE {
#   SERVICE wikibase:mwapi
#           { bd:serviceParam wikibase:api "EntitySearch" .
#            bd:serviceParam wikibase:endpoint "www.wikidata.org" .
#            bd:serviceParam mwapi:search "cascade" .
#            bd:serviceParam mwapi:language "en" .
#            ?item wikibase:apiOutputItem mwapi:item .
#            ?num wikibase:apiOrdinal true .
#           }
# }
# ```
#
# returns a large amount of results.   Reference details about this call at https://www.mediawiki.org/wiki/Wikidata_Query_Service/User_Manual/MWAPI.
#
# Resolving if any of these are in fact a true match is difficult to know.  Even presenting these to a human for assessment is non-trivial.
#
# ## Reporting
#
# Resolving this issue of how to present these results back in an effective and usable manner to data providers is an important aspect.  I am not sure what might be the best approach at this time though it might vary from community to community.

# %% [markdown]
# ## Installs

# %% [markdown]
# ### Pip installs

# %%
# %%capture
# !pip install -q spacy
# !pip install -q scispacy
# !pip install -q mimesis
# !pip install -q minio 
# !pip install -q SPARQLWrapper
# !pip install -q boto3
# !pip install -q rdflib
# !pip install -q rdflib-jsonld
# !pip install -q PyLD==2.0.2
# !pip install -q qwikidata
# !pip install 'fsspec>=0.3.3'
# !pip install s3fs

# %%
# Install a SciSpaCY model
# !pip install -q https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz
# Out:
#      |████████████████████████████████| 17.0MB 233kB/s
#   Building wheel for en-core-sci-sm (setup.py) ... done

# %%
# Install SpaCY Web Large
# !pip install -q https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz
# Out:
#      |████████████████████████████████| 782.7MB 23kB/s
#   Building wheel for en-core-web-lg (setup.py) ... done

# %% [markdown]
# ### Core imports

# %%
# Import packages
import scispacy
import spacy
#import en_core_sci_sm
from spacy import displacy
import pandas as pd
import dask, boto3
import dask.dataframe as dd
# Out:
# /home/fils/.conda/envs/kglab/lib/python3.8/site-packages/dask/dataframe/backends.py:189: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /home/fils/.conda/envs/kglab/lib/python3.8/site-packages/dask/dataframe/backends.py:189: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /home/fils/.conda/envs/kglab/lib/python3.8/site-packages/dask/dataframe/backends.py:189: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %% [markdown]
# ### Helping function(s)
# The following block is a SPARQL to Pandas feature.  You may need to run it to load the function per standard notebook actions.

# %%
#@title
def get_sparql_dataframe(service, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    sparql = SPARQLWrapper(service)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# ### Pandas config

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /tmp/ipykernel_1067711/3462665596.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Gleaner Data
#
# First lets load up some of the data Gleaner has collected.  This is just simple data graph objects and not any graphs or other processed products from Gleaner.

# %%
# Set up our S3FileSystem object
import s3fs 

oss = s3fs.S3FileSystem(
      anon=True,
      key=key,
      secret=secret,
      client_kwargs = {"endpoint_url":"https://oss.geodex.org"}
   )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 # Set up our S3FileSystem object
#       2 import s3fs
#       4 oss = s3fs.S3FileSystem(
#       5       anon=True,
# ----> 6       key=key,
#       7       secret=secret,
#       8       client_kwargs = {"endpoint_url":"https://oss.geodex.org"}
#       9    )
#
# NameError: name 'key' is not defined

# %%
# A simple example of grabbing one item...  

import json 

jld = ""
with oss.open('gleaner/summoned/opentopo/231f7fa996be8bd5c28b64ed42907b65cca5ee30.jsonld', 'rb') as f:
  #print(f.read())
   jld = f.read().decode("utf-8", "ignore").replace('\n',' ')
   json = json.loads(jld)

text = json['name']
print(text)
# Out:
# High Resolution Topography near Santa Cruz, CA 2017

# %%
import json

@dask.delayed()
def read_a_file(fn):
    # or preferably open in text mode and json.load from the file
    with oss.open(fn, 'rb') as f:
        #return json.loads(f.read().replace('\n',' '))
        return json.loads(f.read().decode("utf-8", "ignore").replace('\n',' '))

filenames = oss.ls('gleaner/summoned/opentopo')
output = [read_a_file(f) for f in filenames]

# %%
gldf = pd.DataFrame(columns=['name', 'url', "keywords", "description"])

for doc in range(len(output)):
#for doc in range(10):
  try:
    jld = output[doc].compute()
  except:
    print("Doc has bad encoding")

  # TODO  Really need to flatten and or frame this

  desc = jld["description"]
  kws = jld["keywords"]
  name = jld["name"]
  url = jld["url"]  
  gldf = gldf.append({'name':name, 'url':url, 'keywords':kws, 'description': desc}, ignore_index=True)

# %%
gldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         899 non-null    object
#  1   url          899 non-null    object
#  2   keywords     899 non-null    object
#  3   description  899 non-null    object
# dtypes: object(4)
# memory usage: 28.2+ KB

# %% [markdown]
# ### Quick Check
#
# Lets grab one of our descriptions and feed it through spacy and check our entities.  The datafram ID 122 was a good one to try, feel free to experiment.

# %%
text = gldf.at[122,'description']
print(text)

kwtest = gldf.at[1,'keywords']
print(kwtest)
# Out:
# High lake levels are reducing beach area along the Lake Michigan coastline and allowing wave action to erode the bases of coastal bluffs at the highest rate of the past 30 years. Sediment budget calculations have shown that bluff erosion is the dominant source of sand and gravel-sized particles that are mobilized into beaches and the nearshore system. Researchers have found that the leading cause of bluff erosion is shallow to intermediate depth translational landslides. Therefore, estimating lake sediment budgets depends on an understanding of the mechanisms that lead to landslide failure. This study will provide a comprehensive analysis of bluff stability for bluffs affected by landslide failure coupled with an analysis of bluff composition to determine the composition of sediment contributions of coastal bluffs to the southeast Lake Michigan sediment budget. This dataset is part of a series of repeat surveys documenting temporal changes to a 0.5 km extent of unconsolidated coastal bluff on Lake Michigan.
# ncalm, nevada, fault, california, desert, scarp

# %%
from spacy import displacy
import spacy
import en_core_web_lg  # intersting need for import here...

nlp = en_core_web_lg.load()
doc2 = nlp(text)
displacy_image = displacy.render(doc2, jupyter = True, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">High lake levels are reducing beach area along the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lake Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  coastline and allowing wave action to erode the bases of coastal bluffs at the highest rate of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past 30 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Sediment budget calculations have shown that bluff erosion is the dominant source of sand and gravel-sized particles that are mobilized into beaches and the nearshore system. Researchers have found that the leading cause of bluff erosion is shallow to intermediate depth translational landslides. Therefore, estimating lake sediment budgets depends on an understanding of the mechanisms that lead to landslide failure. This study will provide a comprehensive analysis of bluff stability for bluffs affected by landslide failure coupled with an analysis of bluff composition to determine the composition of sediment contributions of coastal bluffs to the southeast
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lake Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  sediment budget. This dataset is part of a series of repeat surveys documenting temporal changes to a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.5 km
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  extent of unconsolidated coastal bluff on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lake Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>

# %% [markdown]
# ### Description Entities
#
# Now lets loop on all of the data graphs and pull the descriptions.  We will then use spacy to identify entities and hold these for later use.

# %%
from spacy import displacy
import spacy
import en_core_web_lg  # intersting need for import here...

nlp = en_core_web_lg.load()
df2 = pd.DataFrame(columns=['name', 'label', 'text', 'url'])

for i in range(len(gldf)):
  doc3 = nlp( gldf.at[i,'description'])
  for entity in doc3.ents:
    df2 = df2.append({'name': gldf.at[i,'name'], 'label': entity.label_, 'text':entity.text, 'url': gldf.at[i,'url']}, ignore_index=True)

# %%
df2.head(5)
# Out:
#                                                   name   label  \
# 0  High Resolution Topography near Santa Cruz, CA 2017  ORG
# 1  High Resolution Topography near Santa Cruz, CA 2017  ORG
# 2  High Resolution Topography near Santa Cruz, CA 2017  PERSON
# 3  High Resolution Topography near Santa Cruz, CA 2017  ORG
# 4  High Resolution Topography near Santa Cruz, CA 2017  GPE
#
#                                              text  \
# 0  the National Center for Airborne Laser Mapping
# 1  NCALM
# 2  Alison Duvall
# 3  the University of Washington
# 4  Watsonville
#
#                                                                              url
# 0  https://portal.opentopography.org/lidarDataset?opentopoID=OTLAS.042020.6339.2
# 1  https://portal.opentopography.org/lidarDataset?opentopoID=OTLAS.042020.6339.2
# 2  https://portal.opentopography.org/lidarDataset?opentopoID=OTLAS.042020.6339.2
# 3  https://portal.opentopography.org/lidarDataset?opentopoID=OTLAS.042020.6339.2
# 4  https://portal.opentopography.org/lidarDataset?opentopoID=OTLAS.042020.6339.2

# %% [markdown]
# ## Get SWEET labels
#
# Grab the SWEET lables into a data frame to match against.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import shapely

cor = "http://cor.esipfed.org/sparql"

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

swt1 = """
PREFIX ufokn: <http://schema.ufokn.org/core/v1/>
SELECT *
where
{
  # ?sub rdfs:label ?text
}
"""

swtdf = get_sparql_dataframe(cor, swt1)

# %%
swtdf.head(5)
# Out:
#                                                                                             sub  \
# 0  https://www.inf.ufrgs.br/bdi/ontologies/geocoreontology#UFRGS:GeoCoreOntology_age_of
# 1  https://www.inf.ufrgs.br/bdi/ontologies/geocoreontology#UFRGS:GeoCoreOntology_constituted_by
# 2  https://www.inf.ufrgs.br/bdi/ontologies/geocoreontology#UFRGS:GeoCoreOntology_generated_by
# 3  https://www.inf.ufrgs.br/bdi/ontologies/geocoreontology#UFRGS:GeoCoreOntology_generated_in
# 4  https://www.inf.ufrgs.br/bdi/ontologies/geocoreontology#UFRGS:GeoCoreOntology_has_age
#
#              text
# 0  age of
# 1  constituted by
# 2  generated by
# 3  generated in
# 4  has age

# %% [markdown]
# ## Description entities checked against SWEET labels
#
# We can now look for the identified entities in the descriptions aginst the SWEET labels.
#
# ### (Merge the data frames)
#
# We can use some of the pandas goodness like in
# https://stackoverflow.com/questions/61106803/python-panda-search-for-value-in-a-df-from-another-df

# %%
# swtdf and df
# review the following snippet example too
# df_merged = pd.merge(df_address, df_CountryMapping, left_on=df_address["Country"].str.lower(), right_on=df_CountryMapping["NAME"].str.lower(), how="left")

## CHEAT
#dfcheat = df.append({'label': "test label", 'text':"Seasonal ice"}, ignore_index=True)
#dfcheat['text'] = dfcheat['text'].str.lower()

df2['text'] = df2['text'].str.lower()
swtdf['text'] = swtdf['text'].str.lower()

check = df2.merge(swtdf, on=['text'], how='outer').dropna()

# %%
check.head()
# Out:
#                                               name label   text  \
# 1244  Mackenzie, Canterbury, New Zealand 2015       ORG   lidar
# 1245  Jemez River Basin Snow-off Lidar Survey       ORG   lidar
# 1246  Jemez River Basin Snow-off Lidar Survey       ORG   lidar
# 1247  Yosemite National Park, CA: Rockfall Studies  ORG   lidar
# 1248  Hurunui Rivers, Canterbury, New Zealand 2013  ORG   lidar
#
#                                    url  \
# 1244  https://doi.org/10.5069/G99G5JWQ
# 1245  https://doi.org/10.5069/G9RB72JV
# 1246  https://doi.org/10.5069/G9RB72JV
# 1247  https://doi.org/10.5069/G9D798B8
# 1248  https://doi.org/10.5069/G9PC3093
#
#                                                 sub
# 1244  http://sweetontology.net/matrInstrument/LIDAR
# 1245  http://sweetontology.net/matrInstrument/LIDAR
# 1246  http://sweetontology.net/matrInstrument/LIDAR
# 1247  http://sweetontology.net/matrInstrument/LIDAR
# 1248  http://sweetontology.net/matrInstrument/LIDAR

# %%
def display_():     
  pd.set_option("display.max_rows", None)     
  from IPython.core.display import display     
  display(check)

display_()
# Out:
#                                                                               name  \
# 1244   Mackenzie, Canterbury, New Zealand 2015
# 1245   Jemez River Basin Snow-off Lidar Survey
# 1246   Jemez River Basin Snow-off Lidar Survey
# 1247   Yosemite National Park, CA: Rockfall Studies
# 1248   Hurunui Rivers, Canterbury, New Zealand 2013
# 1249   Jemez River Basin Snow-on Lidar Survey
# 1250   Jemez River Basin Snow-on Lidar Survey
# 1251   Marlborough, New Zealand 2018
# 1252   2010 CU-Boulder Campus and Flatirons
# 1253   2010 CU-Boulder Campus and Flatirons
# 1254   2010 CU-Boulder Campus and Flatirons
# 1255   Huntly, Waikato, New Zealand 2015-2019
# 1256   Palmerston North, Manawatu-Whanganui, New Zealand 2018
#
# 1416   Wellington Fault, NZ 2010
# 1417   2010 Channel Islands Lidar Collection
# 1418   Southern Sierra Nevada Critical Zone Observatory: Snow On
# 1419   Auckland, New Zealand 2013
# 1420   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 1421   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2154   IT-Ren, Fluxnet site
# 2155   IT-Ren, Fluxnet site
# 2156   IT-Ren, Fluxnet site
# 2157   IT-Ren, Fluxnet site
# 2828   2008 Iowa River Flood Lidar, Iowa City, and the Clear Creek Watershed
# 2829   2008 Iowa River Flood Lidar, Iowa City, and the Clear Creek Watershed
# 2830   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2831   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2832   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2833   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2834   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2835   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2836   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2837   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2838   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2839   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2840   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2841   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2842   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2843   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2844   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2845   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2846   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2847   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2848   Lava Flow Time Series Experiment, Syracuse, NY
# 2849   Lava Flow Time Series Experiment, Syracuse, NY
# 2850   2008 Iowa River Flood Lidar, Iowa City, and the Clear Creek Watershed
# 2851   2008 Iowa River Flood Lidar, Iowa City, and the Clear Creek Watershed
# 2852   Lost River Fault Zone Near Borah Peak, Idaho
# 2853   Lost River Fault Zone Near Borah Peak, Idaho
# 2854   Lava Flow Time Series Experiment, Syracuse, NY
# 2855   Lava Flow Time Series Experiment, Syracuse, NY
# 2856   Lake Tahoe Basin Lidar
# 2857   Lake Tahoe Basin Lidar
# 2858   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2859   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2860   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2861   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2862   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2863   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 2864   Geomorpho90m - Global High-Resolution Geomorphometric Layers
# 2865   Geomorpho90m - Global High-Resolution Geomorphometric Layers
# 2866   PG&E Diablo Canyon Power Plant (DCPP): Los Osos, CA Central Coast
# 2867   PG&E Diablo Canyon Power Plant (DCPP): Los Osos, CA Central Coast
# 2868   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2869   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2870   Lava Flow Time Series Experiment, Syracuse, NY
# 2871   Lava Flow Time Series Experiment, Syracuse, NY
# 2872   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2873   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 2874   Solfatara Plateau Obsidian Lava Flow, Yellowstone National Park, WY
# 2875   Solfatara Plateau Obsidian Lava Flow, Yellowstone National Park, WY
# 2876   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2877   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2878   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2879   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2880   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2881   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 2882   Lost River Fault Zone Near Borah Peak, Idaho
# 2883   Lost River Fault Zone Near Borah Peak, Idaho
# 2884   Geomorpho90m - Global High-Resolution Geomorphometric Layers
# 2885   Geomorpho90m - Global High-Resolution Geomorphometric Layers
# 2886   PG&E Diablo Canyon Power Plant (DCPP): Los Osos, CA Central Coast
# 2887   PG&E Diablo Canyon Power Plant (DCPP): Los Osos, CA Central Coast
# 2888   2005 San Diego Urban Region Lidar
# 2889   2005 San Diego Urban Region Lidar
# 2890   Hyak, WA:  Cedar River Municipal Watershed Snow Modeling
# 2891   Hyak, WA:  Cedar River Municipal Watershed Snow Modeling
# 2892   Hyak, WA:  Cedar River Municipal Watershed Snow Modeling
# 2893   Hyak, WA:  Cedar River Municipal Watershed Snow Modeling
# 2894   2010 Channel Islands Lidar Collection
# 2895   2010 Channel Islands Lidar Collection
# 2896   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2897   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2898   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2899   PG&E Diablo Canyon Power Plant (DCPP): San Simeon, CA Central Coast
# 2900   Solfatara Plateau Obsidian Lava Flow, Yellowstone National Park, WY
# 2901   Solfatara Plateau Obsidian Lava Flow, Yellowstone National Park, WY
# 3328   Hurunui Rivers, Canterbury, New Zealand 2013
# 3329   Wellington, New Zealand 2013
# 3330   Topographic Data Set: Klamath River, California 2018
# 3331   Topographic Data Set: Klamath River, California 2018
# 3332   Topographic Data Set: Klamath River, California 2018 (State Plane)
# 3333   Topographic Data Set: Klamath River, California 2018 (State Plane)
# 3334   Bilila-Mtakataka Fault - Mua Segment
# 3335   Tauranga and Coast, Bay of Plenty, New Zealand 2015
# 3336   Bilila-Mtakataka Fault - Kasinge Segment
# 3337   Cheviot and Hawarden, Canterbury, New Zealand 2015
# 3338   Post Hurricane Harvey Mapping of the Mission River, Texas 2018 (Ch 1, 2, 3)
# 3339   Richmond and Motueka, Tasman, New Zealand 2015
# 3340   Golden Bay, Tasman, New Zealand 2017
# 3341   Abel Tasman and Golden Bay, Tasman, New Zealand 2016
# 3342   Topographic Data Set: Klamath River, California 2018
# 3343   Topographic Data Set: Klamath River, California 2018
# 3344   2019 Ridgecrest, CA  Pre-Earthquake Digital Surface Model
# 3345   2019 Ridgecrest, CA  Pre-Earthquake Digital Surface Model
# 3661   Greys River, WY (532 nm)
# 3662   Greys River, WY (532 nm)
# 3663   Greys River, WY (1550 nm)
# 3664   Greys River, WY (1550 nm)
# 3665   Greys River, WY
# 3666   Greys River, WY
# 3737   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 3738   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 3739   East Helanshan Fault, northern China
# 3740   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 3741   El Mayor-Cucapah Earthquake, Pleiades 2014
# 3742   Topographic stress controls, San Bernardino Mountains, CA 2017
# 3743   San Rafael River, Castle Dale, Utah, 2016
# 3744   Bilila-Mtakataka Fault - Mua Segment
# 3745   Bilila-Mtakataka Fault - Kasinge Segment
# 3746   Boulder Creek Critical Zone Observatory August 2010 LiDAR Survey
# 3747   Boulder Creek Critical Zone Observatory August 2010 LiDAR Survey
# 3748   Boulder Creek Critical Zone Observatory May 9 2010 Snow-On Lidar Survey
# 3749   Boulder Creek Critical Zone Observatory May 9 2010 Snow-On Lidar Survey
# 3750   San Rafael River, Castle Dale, Utah, 2016
# 3751   Shuttle Radar Topography Mission (SRTM GL1) Global 30m
# 3752   Boulder Creek Critical Zone Observatory May 20-21 2010 Snow-On Lidar Survey
# 3753   Boulder Creek Critical Zone Observatory May 20-21 2010 Snow-On Lidar Survey
# 3754   Boulder Creek Critical Zone Observatory May 5 2010 Snow-On Lidar Survey
# 3755   Boulder Creek Critical Zone Observatory May 5 2010 Snow-On Lidar Survey
# 3756   Boulder Creek Critical Zone Observatory May 5 2010 Snow-On Lidar Survey
# 3757   Boulder Creek Critical Zone Observatory May 5 2010 Snow-On Lidar Survey
# 3758   Boulder Creek Critical Zone Observatory May 9 2010 Snow-On Lidar Survey
# 3759   Boulder Creek Critical Zone Observatory May 9 2010 Snow-On Lidar Survey
# 3760   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 3761   Topographic stress controls, San Bernardino Mountains, CA 2017
# 3762   Topographic stress controls, San Bernardino Mountains, CA 2017
# 3763   Bedrock cliffs in the San Gabriel and San Jacinto Mountains, California
# 3764   Shuttle Radar Topography Mission (SRTM GL3) Global 90m
# 3765   San Rafael River, Castle Dale, Utah, 2016
# 3766   San Rafael River, Castle Dale, Utah, 2016
# 3767   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 3768   Topographic stress controls, San Bernardino Mountains, CA 2017
# 4787   High Resolution Topography of House Range Fault, Utah
# 4788   High Resolution Topography of House Range Fault, Utah
# 4789   High Resolution Topography of House Range Fault, Utah
# 5132   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5133   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5134   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5135   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5136   2010 CU-Boulder Campus and Flatirons
# 5137   2010 CU-Boulder Campus and Flatirons
# 5138   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5139   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5140   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5141   Niwot Ridge Long-Term Ecological Research Site, Colorado
# 5142   Grand Junction, CO: Roan Plateau
# 5143   Grand Junction, CO: Roan Plateau
# 5144   Southwest Flank of Mt.Rainier, WA
# 5145   Southwest Flank of Mt.Rainier, WA
# 5146   West Bijou Creek, CO
# 5147   West Bijou Creek, CO
# 5148   Raleigh Peak, Colorado: May 2010
# 5149   Raleigh Peak, Colorado: May 2010
# 5150   2010 CU-Boulder Campus and Flatirons
# 5151   2010 CU-Boulder Campus and Flatirons
# 5152   Boulder Creek Critical Zone Observatory August 2010 LiDAR Survey
# 5153   Boulder Creek Critical Zone Observatory August 2010 LiDAR Survey
# 5154   Southwest Flank of Mt.Rainier, WA
# 5155   Southwest Flank of Mt.Rainier, WA
# 5156   San Isabel NF, CO: Debris Flow Mechanics and Landscape Evolution
# 5157   San Isabel NF, CO: Debris Flow Mechanics and Landscape Evolution
# 5158   Raleigh Peak, Colorado: May 2010
# 5159   Raleigh Peak, Colorado: May 2010
# 5160   Boulder Creek Critical Zone Observatory August 2010 Snow-Off Lidar Survey
# 5161   Boulder Creek Critical Zone Observatory August 2010 Snow-Off Lidar Survey
# 5162   2019 Ridgecrest, CA  Pre-Earthquake Digital Surface Model
# 5163   2019 Ridgecrest, CA  Pre-Earthquake Digital Surface Model
# 5463   Mt Vettore Fault, San Lorenzo Site, Curly Trench
# 5464   Mt Vettore Fault, Forca di Presta Site, Hope Trench
# 5465   Mt Vettore Fault, San Lorenzo Site, Matthew Trench
# 5558   Clear Creek, Idaho post-fire debris flow erosion
# 5559   Clear Creek, Idaho post-fire debris flow erosion
# 6174   Airborne Laser Mapping of Yosemite National Park, CA, 2007
# 6175   Airborne Laser Mapping of Yosemite National Park, CA, 2007
# 6176   Airborne Laser Mapping of Yosemite National Park, CA, 2007
# 6177   Airborne Laser Mapping of Yosemite National Park, CA, 2007
# 6263   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6264   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6265   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6266   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6267   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6268   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6269   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6270   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6271   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6272   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6273   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6274   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6275   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6276   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6277   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6278   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6279   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6280   Palmerston North, Manawatu-Whanganui, New Zealand 2018
# 6281   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 6282   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 6283   Richmond and Motueka, Tasman, New Zealand 2015
# 6284   Richmond and Motueka, Tasman, New Zealand 2015
# 6285   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 6286   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 6287   Abel Tasman and Golden Bay, Tasman, New Zealand 2016
# 6288   Abel Tasman and Golden Bay, Tasman, New Zealand 2016
# 6559   Kremmling, CO: Blue and Colorado River Confluence
# 6560   Kremmling, CO: Blue and Colorado River Confluence
# 6736   Digital Elevation Model of Dabbahu volcano, Ethiopia (Part 1 of 2)
# 6737   Digital Elevation Model of Dabbahu volcano, Ethiopia (Part 2 of 2)
# 6760   High Resolution Topography of West Helanshan Fault, Northern China 2018
# 6761   High Resolution Topography of West Helanshan Fault, Northern China 2018
# 6946   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6947   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6948   2010 Salton Sea Lidar Collection
# 6949   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6950   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6951   2010 Salton Sea Lidar Collection
# 6956   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6957   Kilauea Volcano, HI July 2018 Acquisition
# 6958   Kilauea Volcano, HI July 2018 Acquisition
# 6959   Kilauea Volcano, HI July 2018 Acquisition
# 6960   Survey of the fluxsite in Muntetschinig, South Tyrol (IT), September 2015
# 6961   Kilauea Volcano, HI July 2018 Acquisition
# 6962   NOAA ISEMP - Watershed Sciences - Bridge Creek, Oregon Lidar Survey, 2005
# 6963   Kilauea Volcano, HI July 2018 Acquisition
# 7031   Photogrammetric model of a portion of the Lee Adoyta Basin, Afar, Ethiopia
# 7051   Photogrammetric model of a portion of the Lee Adoyta Basin, Afar, Ethiopia
# 7053   Photogrammetric model of a portion of the Lee Adoyta Basin, Afar, Ethiopia
# 7193   White Mountain Fault Zone, Owens Valley, CA
# 7194   White Mountain Fault Zone, Owens Valley, CA
# 7195   Volcanic Tablelands in Bishop, California
# 7196   Volcanic Tablelands in Bishop, California
# 7316   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 7317   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 7318   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 7319   Shuttle Radar Topography Mission (SRTM GL1) Global 30m Ellipsoidal
# 7320   ALOS World 3D - 30m Ellipsoidal
# 7321   ALOS World 3D - 30m Ellipsoidal
# 7442   State of Utah Acquired Lidar Data - Wasatch Front
# 7443   State of Utah Acquired Lidar Data - Wasatch Front
# 7444   State of Utah Acquired Lidar Data - Wasatch Front
# 7445   State of Utah Acquired Lidar Data - Wasatch Front
# 7446   Oregon Department of Geology and Mineral Industries Lidar Program Data
# 7447   Oregon Department of Geology and Mineral Industries Lidar Program Data
# 7457   State of Utah Acquired Lidar Data - Wasatch Front
# 7458   State of Utah Acquired Lidar Data - Wasatch Front
# 7519   Susquehanna Shale Hills Critical Zone Observatory: Leaf Off Survey
# 7520   Susquehanna Shale Hills Critical Zone Observatory: Leaf On Survey
# 7521   Susquehanna Shale Hills Critical Zone Observatory: Leaf Off Survey
# 7522   Susquehanna Shale Hills Critical Zone Observatory: Leaf On Survey
# 7625   Rockwalls, Lauterbrunnen Valley, Bernese Oberland, Switzerland, April 2012
# 7626   Rockwalls, Lauterbrunnen Valley, Bernese Oberland, Switzerland, April 2012
# 7838   Tuscaloosa, AL: Seasonal Inundation Dynamics And Invertebrate Communities
# 7839   Tuscaloosa, AL: Seasonal Inundation Dynamics And Invertebrate Communities
# 8450   Pellston, MI: Effects of Forest Canopy Structural Change on Carbon Uptake
# 8451   Pellston, MI: Effects of Forest Canopy Structural Change on Carbon Uptake
# 8452   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 8453   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 8454   Richmond and Motueka, Tasman, New Zealand 2015
# 8455   Richmond and Motueka, Tasman, New Zealand 2015
# 8456   Pellston, MI: Effects of Forest Canopy Structural Change on Carbon Uptake
# 8457   Pellston, MI: Effects of Forest Canopy Structural Change on Carbon Uptake
# 8458   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 8459   Northern California Coast: Slope Failure in Low and High Uplift Regions
# 8460   Abel Tasman and Golden Bay, Tasman, New Zealand 2016
# 8461   Abel Tasman and Golden Bay, Tasman, New Zealand 2016
# 8567   PG&E Diablo Canyon Power Plant (DCPP): Diablo Canyon, CA Central Coast
# 8568   PG&E Diablo Canyon Power Plant (DCPP): Diablo Canyon, CA Central Coast
# 8816   Loma Mar, CA: Lidar survey of the San Jose Mountains
# 8817   Loma Mar, CA: Lidar survey of the San Jose Mountains
# 8882   Eel River Critical Zone Observatory July 2014 Lidar Survey (Eel River)
# 8883   Eel River Critical Zone Observatory July 2014 Lidar Survey (Eel River)
# 8898   Mapping of Diamond Fork River, UT 2017
# 8899   Mapping of Diamond Fork River, UT 2017
# 8900   San Rafael River, Castle Dale, Utah, 2016
# 8901   Straight Cliffs Formation, South-Central Utah, 2016
# 8902   Tushar Mountains, Utah (1550 nm)
# ...
# 6947   http://sweetontology.net/stateTimeFrequency/Annual
# 6948   http://sweetontology.net/stateTimeFrequency/Annual
# 6949   http://sweetontology.net/stateTimeFrequency/Annual
# 6950   http://sweetontology.net/stateTimeFrequency/Annual
# 6951   http://sweetontology.net/stateTimeFrequency/Annual
# 6956   http://sweetontology.net/reprTimeSeason/Summer
# 6957   http://sweetontology.net/reprTimeSeason/Summer
# 6958   http://sweetontology.net/reprTimeSeason/Summer
# 6959   http://sweetontology.net/reprTimeSeason/Summer
# 6960   http://sweetontology.net/reprTimeSeason/Summer
# 6961   http://sweetontology.net/reprTimeSeason/Summer
# 6962   http://sweetontology.net/reprTimeSeason/Summer
# 6963   http://sweetontology.net/reprTimeSeason/Summer
# 7031   http://sweetontology.net/propIndex/BIBI
# 7051   http://purl.obolibrary.org/obo/NCBITaxon_9605
# 7053   http://sweetontology.net/humanKnowledgeDomain/Science
# 7193   http://sweetontology.net/stateTimeGeologic/Pleistocene
# 7194   http://sweetontology.net/stateTimeGeologic/Pleistocene
# 7195   http://sweetontology.net/stateTimeGeologic/Pleistocene
# 7196   http://sweetontology.net/stateTimeGeologic/Pleistocene
# 7316   http://sweetontology.net/matrElementalMolecule/H3
# 7317   http://sweetontology.net/matrIsotope/H3
# 7318   http://sweetontology.net/matrElementalMolecule/H3
# 7319   http://sweetontology.net/matrIsotope/H3
# 7320   http://sweetontology.net/matrElementalMolecule/H3
# 7321   http://sweetontology.net/matrIsotope/H3
# 7442   http://sweetontology.net/humanJurisdiction/State
# 7443   http://sweetontology.net/state/State
# 7444   http://sweetontology.net/humanJurisdiction/State
# 7445   http://sweetontology.net/state/State
# 7446   http://sweetontology.net/humanJurisdiction/State
# 7447   http://sweetontology.net/state/State
# 7457   http://sweetontology.net/phenAtmoPrecipitation/Hurricane
# 7458   http://sweetontology.net/phenAtmoPrecipitation/Hurricane
# 7519   http://sweetontology.net/realm/CriticalZone
# 7520   http://sweetontology.net/realm/CriticalZone
# 7521   http://sweetontology.net/realm/CriticalZone
# 7522   http://sweetontology.net/realm/CriticalZone
# 7625   http://sweetontology.net/repr/3D
# 7626   http://sweetontology.net/repr/3D
# 7838   http://sweetontology.net/matrElement/Al
# 7839   http://sweetontology.net/matrElement/Al
# 8450   http://sweetontology.net/reprSpaceDirection/South
# 8451   http://sweetontology.net/relaSpace/south
# 8452   http://sweetontology.net/reprSpaceDirection/South
# 8453   http://sweetontology.net/relaSpace/south
# 8454   http://sweetontology.net/reprSpaceDirection/South
# 8455   http://sweetontology.net/relaSpace/south
# 8456   http://sweetontology.net/reprSpaceDirection/South
# 8457   http://sweetontology.net/relaSpace/south
# 8458   http://sweetontology.net/reprSpaceDirection/South
# 8459   http://sweetontology.net/relaSpace/south
# 8460   http://sweetontology.net/reprSpaceDirection/South
# 8461   http://sweetontology.net/relaSpace/south
# 8567   http://purl.obolibrary.org/obo/ENVO_00000169
# 8568   http://sweetontology.net/realmLandFluvial/Canyon
# 8816   http://www.w3.org/2006/time#Wednesday
# 8817   http://www.w3.org/2006/time#Wednesday
# 8882   http://sweetontology.net/propSpaceHeight/Bathymetry
# 8883   http://sweetontology.net/propSpaceHeight/Bathymetry
# 8898   http://sweetontology.net/reprTime/UT
# 8899   http://sweetontology.net/reprTime/UT
# 8900   http://sweetontology.net/reprTime/UT
# 8901   http://sweetontology.net/reprTime/UT
# 8902   http://sweetontology.net/reprTime/UT
# 8903   http://sweetontology.net/reprTime/UT
# 8904   http://sweetontology.net/reprTime/UT
# 8905   http://sweetontology.net/reprTime/UT
# 8906   http://sweetontology.net/reprTime/UT
# 8907   http://sweetontology.net/reprTime/UT
# 8908   http://sweetontology.net/reprTime/UT
# 8909   http://sweetontology.net/reprTime/UT
# 8910   http://sweetontology.net/reprTime/UT
# 8911   http://sweetontology.net/reprTime/UT
# 8912   http://sweetontology.net/reprTime/UT
# 8913   http://sweetontology.net/reprTime/UT
# 8914   http://sweetontology.net/reprTime/UT
# 8915   http://sweetontology.net/reprTime/UT
# 8916   http://sweetontology.net/reprTime/UT
# 8917   http://sweetontology.net/reprTime/UT
# 8918   http://sweetontology.net/reprTime/UT
# 8919   http://sweetontology.net/reprTime/UT
# 8920   http://sweetontology.net/reprTime/UT
# 8921   http://sweetontology.net/reprTime/UT
# 8922   http://sweetontology.net/reprTime/UT
# 8923   http://sweetontology.net/reprTime/UT
# 8924   http://sweetontology.net/reprTime/UT
# 8925   http://sweetontology.net/reprTime/UT
# 8926   http://sweetontology.net/reprTime/UT
# 9113   http://sweetontology.net/reprTimeDay/Morning
# 9114   http://sweetontology.net/reprTimeDay/Morning
# 9499   http://sweetontology.net/realm/Geosphere
# 9500   http://sweetontology.net/realm/Geosphere
# 9501   http://sweetontology.net/realm/Geosphere
# 9502   http://sweetontology.net/realm/Geosphere
# 9503   http://sweetontology.net/realm/Geosphere
# 9715   http://sweetontology.net/relaSpace/east
# 9716   http://sweetontology.net/reprSpaceDirection/East
# 9717   http://sweetontology.net/relaSpace/east
# 9718   http://sweetontology.net/reprSpaceDirection/East
# 9719   http://sweetontology.net/relaSpace/east
# 9720   http://sweetontology.net/reprSpaceDirection/East
# 9721   http://sweetontology.net/relaSpace/east
# 9722   http://sweetontology.net/reprSpaceDirection/East
# 9723   http://sweetontology.net/relaSpace/west
# 9724   http://sweetontology.net/reprSpaceDirection/West
# 9725   http://sweetontology.net/relaSpace/west
# 9726   http://sweetontology.net/reprSpaceDirection/West
# 9727   http://sweetontology.net/relaSpace/west
# 9728   http://sweetontology.net/reprSpaceDirection/West
# 9729   http://sweetontology.net/relaSpace/west
# 9730   http://sweetontology.net/reprSpaceDirection/West
# 9731   http://sweetontology.net/relaSpace/west
# 9732   http://sweetontology.net/reprSpaceDirection/West
# 9733   http://sweetontology.net/relaSpace/west
# 9734   http://sweetontology.net/reprSpaceDirection/West
# 9735   http://sweetontology.net/relaSpace/west
# 9736   http://sweetontology.net/reprSpaceDirection/West
# 9737   http://sweetontology.net/relaSpace/west
# 9738   http://sweetontology.net/reprSpaceDirection/West
# 9841   http://sweetontology.net/stateTimeFrequency/Seasonal
# 9842   http://sweetontology.net/stateTimeFrequency/Seasonal
# 9843   http://sweetontology.net/stateTimeFrequency/Seasonal
# 9844   http://sweetontology.net/stateTimeFrequency/Seasonal
# 10038  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10039  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10040  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10041  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10042  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10043  http://webprotege.stanford.edu/RxBjBUxQpjJ8iAQOqbME9T
# 10533  http://sweetontology.net/humanJurisdiction/County
# 10534  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10535  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10536  http://sweetontology.net/humanJurisdiction/County
# 10537  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10538  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10539  http://sweetontology.net/humanJurisdiction/County
# 10540  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10541  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10542  http://sweetontology.net/humanJurisdiction/County
# 10543  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10544  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10545  http://sweetontology.net/humanJurisdiction/County
# 10546  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10547  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10548  http://sweetontology.net/humanJurisdiction/County
# 10549  http://mmisw.org/ont/ioos/marine_biogeography/county
# 10550  http://webprotege.stanford.edu/RC4ZciE8f3bSR9g3girvRI9
# 10689  http://sweetontology.net/matrSediment/Clay
# 10690  http://purl.obolibrary.org/obo/ENVO_00002982
# 10691  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10692  http://sweetontology.net/matrSediment/Clay
# 10693  http://purl.obolibrary.org/obo/ENVO_00002982
# 10694  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10695  http://sweetontology.net/matrSediment/Clay
# 10696  http://purl.obolibrary.org/obo/ENVO_00002982
# 10697  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10698  http://sweetontology.net/matrSediment/Clay
# 10699  http://purl.obolibrary.org/obo/ENVO_00002982
# 10700  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10701  http://sweetontology.net/matrSediment/Clay
# 10702  http://purl.obolibrary.org/obo/ENVO_00002982
# 10703  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10704  http://sweetontology.net/matrSediment/Clay
# 10705  http://purl.obolibrary.org/obo/ENVO_00002982
# 10706  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10707  http://sweetontology.net/matrSediment/Clay
# 10708  http://purl.obolibrary.org/obo/ENVO_00002982
# 10709  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10710  http://sweetontology.net/matrSediment/Clay
# 10711  http://purl.obolibrary.org/obo/ENVO_00002982
# 10712  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10713  http://sweetontology.net/matrSediment/Clay
# 10714  http://purl.obolibrary.org/obo/ENVO_00002982
# 10715  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10716  http://sweetontology.net/matrSediment/Clay
# 10717  http://purl.obolibrary.org/obo/ENVO_00002982
# 10718  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10719  http://sweetontology.net/matrSediment/Clay
# 10720  http://purl.obolibrary.org/obo/ENVO_00002982
# 10721  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10722  http://sweetontology.net/matrSediment/Clay
# 10723  http://purl.obolibrary.org/obo/ENVO_00002982
# 10724  urn:cgi:classifier:CGI:LithologyOWL:201001:clay
# 10901  http://sweetontology.net/stateSpectralBand/Orange
# 10902  http://sweetontology.net/stateSpectralBand/Orange
# 10903  http://sweetontology.net/stateSpectralBand/Orange
# 10904  http://sweetontology.net/stateSpectralBand/Orange
# 10905  http://sweetontology.net/stateSpectralBand/Orange
# 10906  http://sweetontology.net/stateSpectralBand/Orange
# 10991  http://sweetontology.net/reprSciUnits/henry
# 10992  http://sweetontology.net/reprSciUnits/henry
# 10993  http://sweetontology.net/reprSciUnits/henry
# 10994  http://sweetontology.net/reprSciUnits/henry
# 10995  http://sweetontology.net/reprSciUnits/henry
# 10996  http://sweetontology.net/reprSciUnits/henry
# 11076  http://sweetontology.net/reprSciUnits/newton
# 11077  http://sweetontology.net/reprSciUnits/newton
# 11078  http://sweetontology.net/reprSciUnits/newton
# 11079  http://sweetontology.net/reprSciUnits/newton
# 11080  http://sweetontology.net/reprSciUnits/newton
# 11081  http://sweetontology.net/reprSciUnits/newton
# 11430  http://sweetontology.net/matrElement/Cu
# 11903  http://purl.obolibrary.org/obo/ENVO_00000287
# 11904  http://sweetontology.net/realmLandOrographic/Butte
# 11905  http://purl.obolibrary.org/obo/ENVO_00000287
# 11906  http://sweetontology.net/realmLandOrographic/Butte
# 12772  http://purl.obolibrary.org/obo/ENVO_00000100
# 12773  http://sweetontology.net/realmLandFluvial/Valley
# 12774  http://purl.obolibrary.org/obo/ENVO_00000100
# 12775  http://sweetontology.net/realmLandFluvial/Valley
# 12776  http://purl.obolibrary.org/obo/ENVO_00000100
# 12777  http://sweetontology.net/realmLandFluvial/Valley
# 12778  http://purl.obolibrary.org/obo/ENVO_00000100
# 12779  http://sweetontology.net/realmLandFluvial/Valley
# 12780  http://purl.obolibrary.org/obo/ENVO_00000100
# 12781  http://sweetontology.net/realmLandFluvial/Valley
# 12865  http://sweetontology.net/matrSediment/Gravel
# 12866  http://purl.obolibrary.org/obo/ENVO_01000018
# 12867  urn:cgi:classifier:CGI:LithologyOWL:201001:gravel
# 12874  http://www.w3.org/2006/time#Sunday
# 12929  http://sweetontology.net/stateRole/Secondary
# 13001  http://sweetontology.net/reprDataFormat/ASCII
# 13002  http://sweetontology.net/reprDataFormat/ASCII
# 13003  http://sweetontology.net/reprDataFormat/ASCII
# 13152  http://sweetontology.net/stateTimeGeologic/Precambrian
# 13442  http://sweetontology.net/stateRealm/Oceanic
# 13443  http://sweetontology.net/stateRealm/Oceanic
# 13541  http://schema.geolink.org/1.0/base/main#Dataset
# 13542  http://sweetontology.net/reprDataProduct/Dataset
# 13543  http://vivoweb.org/ontology/core#Dataset
# 13588  http://purl.obolibrary.org/obo/ENVO_00000032
# 13589  http://sweetontology.net/realmHydroBody/Bay
# 13649  http://sweetontology.net/reprMathFunction/Horizon
# 13667  http://purl.obolibrary.org/obo/ENVO_00000562
# 13668  http://sweetontology.net/realmLandProtected/Park
# 13724  http://purl.obolibrary.org/obo/ENVO_01000207
# 13725  http://purl.obolibrary.org/obo/ENVO_01000207
# 13726  http://purl.obolibrary.org/obo/ENVO_01000207
# 13727  http://purl.obolibrary.org/obo/ENVO_01000207
# 13802  http://sweetontology.net/reprDataProduct/Data
# 13803  http://purl.dataone.org/provone/2015/01/15/ontology#Data

# %% [markdown]
# ## Keyword check against SWEET Lables
#
# ### ToDo
# Do lookup based on Keywords
